# %%
import pandas as pd 
import matplotlib.pyplot as plt 
# %matplotlib inline
import seaborn as sns
import numpy as np

from sklearn.linear_model import LinearRegression # linear regression model
from sklearn.model_selection import train_test_split # for splitting the data into training and testing sets
from sklearn.metrics import r2_score

games = pd.read_csv('games.csv')
players = pd.read_csv('players.csv')
stats = pd.read_csv('stats.csv')
#games.head() 
#players.head() 
stats.head()
# Out:
#      gameId      team  year round    playerId      displayName  gameNumber  \
# 0  2021R104  Adelaide  2021    R1  2021661124       Berry, Sam           1
# 1  2021R104  Adelaide  2021    R1  2012662083      Brown, Luke         168
# 2  2021R104  Adelaide  2021    R1  2020665315    Butts, Jordon           3
# 3  2021R104  Adelaide  2021    R1  2018689604      Doedee, Tom          31
# 4  2021R104  Adelaide  2021    R1  2018703883  Frampton, Billy           9
#
#    Disposals  Kicks  Marks  ...  Brownlow Votes  Contested Possessions  \
# 0          8      6      1  ...               0                      4
# 1          5      2      0  ...               0                      2
# 2         10      5      3  ...               0                      5
# 3         13      9      4  ...               0                      8
# 4         14     10      8  ...               0                      5
#
#    Uncontested Possessions  Contested Marks  Marks Inside 50  One Percenters  \
# ...

# %%
seasonal1=stats[(stats['year']==2021)&(stats['round']=='R1')]
seasonal2=stats[(stats['year']==2021)&(stats['round']=='R2')]
seasonal3=stats[(stats['year']==2021)&(stats['round']=='R3')]
seasonal4=stats[(stats['year']==2021)&(stats['round']=='R4')]
seasonal5=stats[(stats['year']==2021)&(stats['round']=='R5')]
seasonal6=stats[(stats['year']==2021)&(stats['round']=='R6')]
seasonal7=stats[(stats['year']==2021)&(stats['round']=='R7')]
seasonal8=stats[(stats['year']==2021)&(stats['round']=='R8')]
seasonal9=stats[(stats['year']==2021)&(stats['round']=='R9')]
seasonal10=stats[(stats['year']==2021)&(stats['round']=='R10')]
seasonal11=stats[(stats['year']==2021)&(stats['round']=='R11')]
seasonal12=stats[(stats['year']==2021)&(stats['round']=='R12')]
seasonal13=stats[(stats['year']==2021)&(stats['round']=='R13')]
seasonal14=stats[(stats['year']==2021)&(stats['round']=='R14')]
seasonal15=stats[(stats['year']==2021)&(stats['round']=='R15')]
seasonal16=stats[(stats['year']==2021)&(stats['round']=='R16')]
seasonal17=stats[(stats['year']==2021)&(stats['round']=='R17')]
seasonal18=stats[(stats['year']==2021)&(stats['round']=='R18')]
seasonal19=stats[(stats['year']==2021)&(stats['round']=='R19')]
seasonal20=stats[(stats['year']==2021)&(stats['round']=='R20')]
seasonal21=stats[(stats['year']==2021)&(stats['round']=='R21')]
seasonal22=stats[(stats['year']==2021)&(stats['round']=='R22')]
seasonal23=stats[(stats['year']==2021)&(stats['round']=='R23')]
season2021=pd.concat([seasonal1,seasonal2,seasonal3,seasonal4,seasonal5,seasonal6,seasonal7,seasonal8,seasonal9,seasonal10,seasonal11,seasonal12,seasonal13,seasonal14,seasonal15,seasonal16,seasonal17,seasonal18,seasonal19,seasonal20,seasonal21,seasonal22,seasonal23])
table2021=season2021.pivot_table(index='team',values=['Marks'],aggfunc='sum')

table2021.sort_values(by='Marks',ascending=False)
# Out:
#                         Marks
# team
# West Coast               2363
# Collingwood              2360
# Gold Coast               2309
# Geelong                  2308
# North Melbourne          2195
# St Kilda                 2127
# Carlton                  2098
# Brisbane Lions           2081
# Sydney                   2081
# Port Adelaide            2073
# Hawthorn                 2053
# Essendon                 2048
# Greater Western Sydney   2020
# Melbourne                1997
# Richmond                 1983
# Fremantle                1980
# Western Bulldogs         1931
# Adelaide                 1758

# %%
seasonal1=stats[(stats['year']==2020)&(stats['round']=='R1')]
seasonal2=stats[(stats['year']==2020)&(stats['round']=='R2')]
seasonal3=stats[(stats['year']==2020)&(stats['round']=='R3')]
seasonal4=stats[(stats['year']==2020)&(stats['round']=='R4')]
seasonal5=stats[(stats['year']==2020)&(stats['round']=='R5')]
seasonal6=stats[(stats['year']==2020)&(stats['round']=='R6')]
seasonal7=stats[(stats['year']==2020)&(stats['round']=='R7')]
seasonal8=stats[(stats['year']==2020)&(stats['round']=='R8')]
seasonal9=stats[(stats['year']==2020)&(stats['round']=='R9')]
seasonal10=stats[(stats['year']==2020)&(stats['round']=='R10')]
seasonal11=stats[(stats['year']==2020)&(stats['round']=='R11')]
seasonal12=stats[(stats['year']==2020)&(stats['round']=='R12')]
seasonal13=stats[(stats['year']==2020)&(stats['round']=='R13')]
seasonal14=stats[(stats['year']==2020)&(stats['round']=='R14')]
seasonal15=stats[(stats['year']==2020)&(stats['round']=='R15')]
seasonal16=stats[(stats['year']==2020)&(stats['round']=='R16')]
seasonal17=stats[(stats['year']==2020)&(stats['round']=='R17')]
seasonal18=stats[(stats['year']==2020)&(stats['round']=='R18')]
seasonal19=stats[(stats['year']==2020)&(stats['round']=='R19')]
seasonal20=stats[(stats['year']==2020)&(stats['round']=='R20')]
seasonal21=stats[(stats['year']==2020)&(stats['round']=='R21')]
seasonal22=stats[(stats['year']==2020)&(stats['round']=='R22')]
seasonal23=stats[(stats['year']==2020)&(stats['round']=='R23')]
season2020=pd.concat([seasonal1,seasonal2,seasonal3,seasonal4,seasonal5,seasonal6,seasonal7,seasonal8,seasonal9,seasonal10,seasonal11,seasonal12,seasonal13,seasonal14,seasonal15,seasonal16,seasonal17,seasonal18,seasonal19,seasonal20,seasonal21,seasonal22,seasonal23])
table2020=season2020.pivot_table(index='team',values=['Marks'],aggfunc='sum')
table2020.sort_values(by='Marks',ascending=False)
# Out:
#                         Marks
# team
# Geelong                  1422
# West Coast               1331
# Brisbane Lions           1308
# St Kilda                 1262
# Greater Western Sydney   1244
# Richmond                 1244
# Collingwood              1238
# Fremantle                1231
# Melbourne                1212
# Carlton                  1200
# Port Adelaide            1171
# Gold Coast               1140
# Hawthorn                 1122
# Essendon                 1121
# Sydney                   1116
# Western Bulldogs         1089
# North Melbourne          1084
# Adelaide                 1006

# %%
seasonal1=stats[(stats['year']==2019)&(stats['round']=='R1')]
seasonal2=stats[(stats['year']==2019)&(stats['round']=='R2')]
seasonal3=stats[(stats['year']==2019)&(stats['round']=='R3')]
seasonal4=stats[(stats['year']==2019)&(stats['round']=='R4')]
seasonal5=stats[(stats['year']==2019)&(stats['round']=='R5')]
seasonal6=stats[(stats['year']==2019)&(stats['round']=='R6')]
seasonal7=stats[(stats['year']==2019)&(stats['round']=='R7')]
seasonal8=stats[(stats['year']==2019)&(stats['round']=='R8')]
seasonal9=stats[(stats['year']==2019)&(stats['round']=='R9')]
seasonal10=stats[(stats['year']==2019)&(stats['round']=='R10')]
seasonal11=stats[(stats['year']==2019)&(stats['round']=='R11')]
seasonal12=stats[(stats['year']==2019)&(stats['round']=='R12')]
seasonal13=stats[(stats['year']==2019)&(stats['round']=='R13')]
seasonal14=stats[(stats['year']==2019)&(stats['round']=='R14')]
seasonal15=stats[(stats['year']==2019)&(stats['round']=='R15')]
seasonal16=stats[(stats['year']==2019)&(stats['round']=='R16')]
seasonal17=stats[(stats['year']==2019)&(stats['round']=='R17')]
seasonal18=stats[(stats['year']==2019)&(stats['round']=='R18')]
seasonal19=stats[(stats['year']==2019)&(stats['round']=='R19')]
seasonal20=stats[(stats['year']==2019)&(stats['round']=='R20')]
seasonal21=stats[(stats['year']==2019)&(stats['round']=='R21')]
seasonal22=stats[(stats['year']==2019)&(stats['round']=='R22')]
seasonal23=stats[(stats['year']==2019)&(stats['round']=='R23')]
season2019=pd.concat([seasonal1,seasonal2,seasonal3,seasonal4,seasonal5,seasonal6,seasonal7,seasonal8,seasonal9,seasonal10,seasonal11,seasonal12,seasonal13,seasonal14,seasonal15,seasonal16,seasonal17,seasonal18,seasonal19,seasonal20,seasonal21,seasonal22,seasonal23])
table2019=season2019.pivot_table(index='team',values=['Marks'],aggfunc='sum')
table2019.sort_values(by='Marks',ascending=False)
# Out:
#                         Marks
# team
# Greater Western Sydney   2341
# Collingwood              2308
# West Coast               2164
# Adelaide                 2080
# Western Bulldogs         2059
# Hawthorn                 2018
# Sydney                   2001
# St Kilda                 1998
# Geelong                  1994
# Carlton                  1992
# Brisbane Lions           1974
# Richmond                 1943
# Port Adelaide            1932
# Essendon                 1919
# Melbourne                1916
# Gold Coast               1908
# Fremantle                1880
# North Melbourne          1791

# %%
seasonal1=stats[(stats['year']==2018)&(stats['round']=='R1')]
seasonal2=stats[(stats['year']==2018)&(stats['round']=='R2')]
seasonal3=stats[(stats['year']==2018)&(stats['round']=='R3')]
seasonal4=stats[(stats['year']==2018)&(stats['round']=='R4')]
seasonal5=stats[(stats['year']==2018)&(stats['round']=='R5')]
seasonal6=stats[(stats['year']==2018)&(stats['round']=='R6')]
seasonal7=stats[(stats['year']==2018)&(stats['round']=='R7')]
seasonal8=stats[(stats['year']==2018)&(stats['round']=='R8')]
seasonal9=stats[(stats['year']==2018)&(stats['round']=='R9')]
seasonal10=stats[(stats['year']==2018)&(stats['round']=='R10')]
seasonal11=stats[(stats['year']==2018)&(stats['round']=='R11')]
seasonal12=stats[(stats['year']==2018)&(stats['round']=='R12')]
seasonal13=stats[(stats['year']==2018)&(stats['round']=='R13')]
seasonal14=stats[(stats['year']==2018)&(stats['round']=='R14')]
seasonal15=stats[(stats['year']==2018)&(stats['round']=='R15')]
seasonal16=stats[(stats['year']==2018)&(stats['round']=='R16')]
seasonal17=stats[(stats['year']==2018)&(stats['round']=='R17')]
seasonal18=stats[(stats['year']==2018)&(stats['round']=='R18')]
seasonal19=stats[(stats['year']==2018)&(stats['round']=='R19')]
seasonal20=stats[(stats['year']==2018)&(stats['round']=='R20')]
seasonal21=stats[(stats['year']==2018)&(stats['round']=='R21')]
seasonal22=stats[(stats['year']==2018)&(stats['round']=='R22')]
seasonal23=stats[(stats['year']==2018)&(stats['round']=='R23')]
season2018=pd.concat([seasonal1,seasonal2,seasonal3,seasonal4,seasonal5,seasonal6,seasonal7,seasonal8,seasonal9,seasonal10,seasonal11,seasonal12,seasonal13,seasonal14,seasonal15,seasonal16,seasonal17,seasonal18,seasonal19,seasonal20,seasonal21,seasonal22,seasonal23])
table2018=season2018.pivot_table(index='team',values=['Marks'],aggfunc='sum')
table2018.sort_values(by='Marks',ascending=False)
# Out:
#                         Marks
# team
# West Coast               2229
# Brisbane Lions           2184
# Essendon                 2122
# Hawthorn                 2070
# St Kilda                 2067
# Collingwood              2041
# Fremantle                2016
# Adelaide                 2014
# Geelong                  1989
# Port Adelaide            1988
# Western Bulldogs         1972
# Sydney                   1947
# Greater Western Sydney   1935
# Melbourne                1924
# Carlton                  1910
# Richmond                 1826
# North Melbourne          1820
# Gold Coast               1703

# %%
seasonal1=stats[(stats['year']==2017)&(stats['round']=='R1')]
seasonal2=stats[(stats['year']==2017)&(stats['round']=='R2')]
seasonal3=stats[(stats['year']==2017)&(stats['round']=='R3')]
seasonal4=stats[(stats['year']==2017)&(stats['round']=='R4')]
seasonal5=stats[(stats['year']==2017)&(stats['round']=='R5')]
seasonal6=stats[(stats['year']==2017)&(stats['round']=='R6')]
seasonal7=stats[(stats['year']==2017)&(stats['round']=='R7')]
seasonal8=stats[(stats['year']==2017)&(stats['round']=='R8')]
seasonal9=stats[(stats['year']==2017)&(stats['round']=='R9')]
seasonal10=stats[(stats['year']==2017)&(stats['round']=='R10')]
seasonal11=stats[(stats['year']==2017)&(stats['round']=='R11')]
seasonal12=stats[(stats['year']==2017)&(stats['round']=='R12')]
seasonal13=stats[(stats['year']==2017)&(stats['round']=='R13')]
seasonal14=stats[(stats['year']==2017)&(stats['round']=='R14')]
seasonal15=stats[(stats['year']==2017)&(stats['round']=='R15')]
seasonal16=stats[(stats['year']==2017)&(stats['round']=='R16')]
seasonal17=stats[(stats['year']==2017)&(stats['round']=='R17')]
seasonal18=stats[(stats['year']==2017)&(stats['round']=='R18')]
seasonal19=stats[(stats['year']==2017)&(stats['round']=='R19')]
seasonal20=stats[(stats['year']==2017)&(stats['round']=='R20')]
seasonal21=stats[(stats['year']==2017)&(stats['round']=='R21')]
seasonal22=stats[(stats['year']==2017)&(stats['round']=='R22')]
seasonal23=stats[(stats['year']==2017)&(stats['round']=='R23')]
season2017=pd.concat([seasonal1,seasonal2,seasonal3,seasonal4,seasonal5,seasonal6,seasonal7,seasonal8,seasonal9,seasonal10,seasonal11,seasonal12,seasonal13,seasonal14,seasonal15,seasonal16,seasonal17,seasonal18,seasonal19,seasonal20,seasonal21,seasonal22,seasonal23])
table2017=season2017.pivot_table(index='team',values=['Marks'],aggfunc='sum')
table2017.sort_values(by='Marks',ascending=False)
# Out:
#                         Marks
# team
# Collingwood              2326
# Essendon                 2305
# Carlton                  2288
# Hawthorn                 2274
# West Coast               2158
# Gold Coast               2120
# Port Adelaide            2085
# Brisbane Lions           2067
# St Kilda                 2050
# Sydney                   2002
# Fremantle                1998
# Greater Western Sydney   1972
# Adelaide                 1969
# Geelong                  1899
# Richmond                 1888
# Melbourne                1883
# Western Bulldogs         1849
# North Melbourne          1828

# %%
seasonal1=stats[(stats['year']==2016)&(stats['round']=='R1')]
seasonal2=stats[(stats['year']==2016)&(stats['round']=='R2')]
seasonal3=stats[(stats['year']==2016)&(stats['round']=='R3')]
seasonal4=stats[(stats['year']==2016)&(stats['round']=='R4')]
seasonal5=stats[(stats['year']==2016)&(stats['round']=='R5')]
seasonal6=stats[(stats['year']==2016)&(stats['round']=='R6')]
seasonal7=stats[(stats['year']==2016)&(stats['round']=='R7')]
seasonal8=stats[(stats['year']==2016)&(stats['round']=='R8')]
seasonal9=stats[(stats['year']==2016)&(stats['round']=='R9')]
seasonal10=stats[(stats['year']==2016)&(stats['round']=='R10')]
seasonal11=stats[(stats['year']==2016)&(stats['round']=='R11')]
seasonal12=stats[(stats['year']==2016)&(stats['round']=='R12')]
seasonal13=stats[(stats['year']==2016)&(stats['round']=='R13')]
seasonal14=stats[(stats['year']==2016)&(stats['round']=='R14')]
seasonal15=stats[(stats['year']==2016)&(stats['round']=='R15')]
seasonal16=stats[(stats['year']==2016)&(stats['round']=='R16')]
seasonal17=stats[(stats['year']==2016)&(stats['round']=='R17')]
seasonal18=stats[(stats['year']==2016)&(stats['round']=='R18')]
seasonal19=stats[(stats['year']==2016)&(stats['round']=='R19')]
seasonal20=stats[(stats['year']==2016)&(stats['round']=='R20')]
seasonal21=stats[(stats['year']==2016)&(stats['round']=='R21')]
seasonal22=stats[(stats['year']==2016)&(stats['round']=='R22')]
seasonal23=stats[(stats['year']==2016)&(stats['round']=='R23')]
season2016=pd.concat([seasonal1,seasonal2,seasonal3,seasonal4,seasonal5,seasonal6,seasonal7,seasonal8,seasonal9,seasonal10,seasonal11,seasonal12,seasonal13,seasonal14,seasonal15,seasonal16,seasonal17,seasonal18,seasonal19,seasonal20,seasonal21,seasonal22,seasonal23])
table2016=season2016.pivot_table(index='team',values=['Marks'],aggfunc='sum')
table2016.sort_values(by='Marks',ascending=False)
# Out:
#                         Marks
# team
# Essendon                 2238
# Geelong                  2159
# Richmond                 2140
# Adelaide                 2097
# Greater Western Sydney   2088
# Western Bulldogs         2049
# Hawthorn                 2043
# St Kilda                 2029
# Carlton                  1977
# Collingwood              1968
# Gold Coast               1921
# West Coast               1900
# North Melbourne          1895
# Fremantle                1871
# Melbourne                1792
# Sydney                   1784
# Port Adelaide            1626
# Brisbane Lions           1600

# %%
seasonal1=stats[(stats['year']==2015)&(stats['round']=='R1')]
seasonal2=stats[(stats['year']==2015)&(stats['round']=='R2')]
seasonal3=stats[(stats['year']==2015)&(stats['round']=='R3')]
seasonal4=stats[(stats['year']==2015)&(stats['round']=='R4')]
seasonal5=stats[(stats['year']==2015)&(stats['round']=='R5')]
seasonal6=stats[(stats['year']==2015)&(stats['round']=='R6')]
seasonal7=stats[(stats['year']==2015)&(stats['round']=='R7')]
seasonal8=stats[(stats['year']==2015)&(stats['round']=='R8')]
seasonal9=stats[(stats['year']==2015)&(stats['round']=='R9')]
seasonal10=stats[(stats['year']==2015)&(stats['round']=='R10')]
seasonal11=stats[(stats['year']==2015)&(stats['round']=='R11')]
seasonal12=stats[(stats['year']==2015)&(stats['round']=='R12')]
seasonal13=stats[(stats['year']==2015)&(stats['round']=='R13')]
seasonal14=stats[(stats['year']==2015)&(stats['round']=='R14')]
seasonal15=stats[(stats['year']==2015)&(stats['round']=='R15')]
seasonal16=stats[(stats['year']==2015)&(stats['round']=='R16')]
seasonal17=stats[(stats['year']==2015)&(stats['round']=='R17')]
seasonal18=stats[(stats['year']==2015)&(stats['round']=='R18')]
seasonal19=stats[(stats['year']==2015)&(stats['round']=='R19')]
seasonal20=stats[(stats['year']==2015)&(stats['round']=='R20')]
seasonal21=stats[(stats['year']==2015)&(stats['round']=='R21')]
seasonal22=stats[(stats['year']==2015)&(stats['round']=='R22')]
seasonal23=stats[(stats['year']==2015)&(stats['round']=='R23')]
season2015=pd.concat([seasonal1,seasonal2,seasonal3,seasonal4,seasonal5,seasonal6,seasonal7,seasonal8,seasonal9,seasonal10,seasonal11,seasonal12,seasonal13,seasonal14,seasonal15,seasonal16,seasonal17,seasonal18,seasonal19,seasonal20,seasonal21,seasonal22,seasonal23])
table2015=season2015.pivot_table(index='team',values=['Marks'],aggfunc='sum')
table2015.sort_values(by='Marks',ascending=False)
# Out:
#                         Marks
# team
# Hawthorn                 2245
# Richmond                 2130
# St Kilda                 2120
# Essendon                 2104
# Fremantle                2069
# Sydney                   2046
# Geelong                  2039
# West Coast               2024
# Greater Western Sydney   2020
# Brisbane Lions           1975
# North Melbourne          1928
# Adelaide                 1926
# Port Adelaide            1924
# Western Bulldogs         1915
# Carlton                  1838
# Collingwood              1834
# Melbourne                1785
# Gold Coast               1676

# %%
seasonal1=stats[(stats['year']==2014)&(stats['round']=='R1')]
seasonal2=stats[(stats['year']==2014)&(stats['round']=='R2')]
seasonal3=stats[(stats['year']==2014)&(stats['round']=='R3')]
seasonal4=stats[(stats['year']==2014)&(stats['round']=='R4')]
seasonal5=stats[(stats['year']==2014)&(stats['round']=='R5')]
seasonal6=stats[(stats['year']==2014)&(stats['round']=='R6')]
seasonal7=stats[(stats['year']==2014)&(stats['round']=='R7')]
seasonal8=stats[(stats['year']==2014)&(stats['round']=='R8')]
seasonal9=stats[(stats['year']==2014)&(stats['round']=='R9')]
seasonal10=stats[(stats['year']==2014)&(stats['round']=='R10')]
seasonal11=stats[(stats['year']==2014)&(stats['round']=='R11')]
seasonal12=stats[(stats['year']==2014)&(stats['round']=='R12')]
seasonal13=stats[(stats['year']==2014)&(stats['round']=='R13')]
seasonal14=stats[(stats['year']==2014)&(stats['round']=='R14')]
seasonal15=stats[(stats['year']==2014)&(stats['round']=='R15')]
seasonal16=stats[(stats['year']==2014)&(stats['round']=='R16')]
seasonal17=stats[(stats['year']==2014)&(stats['round']=='R17')]
seasonal18=stats[(stats['year']==2014)&(stats['round']=='R18')]
seasonal19=stats[(stats['year']==2014)&(stats['round']=='R19')]
seasonal20=stats[(stats['year']==2014)&(stats['round']=='R20')]
seasonal21=stats[(stats['year']==2014)&(stats['round']=='R21')]
seasonal22=stats[(stats['year']==2014)&(stats['round']=='R22')]
seasonal23=stats[(stats['year']==2014)&(stats['round']=='R23')]
season2014=pd.concat([seasonal1,seasonal2,seasonal3,seasonal4,seasonal5,seasonal6,seasonal7,seasonal8,seasonal9,seasonal10,seasonal11,seasonal12,seasonal13,seasonal14,seasonal15,seasonal16,seasonal17,seasonal18,seasonal19,seasonal20,seasonal21,seasonal22,seasonal23])
table2014=season2014.pivot_table(index='team',values=['Marks'],aggfunc='sum')
table2014.sort_values(by='Marks',ascending=False)
# Out:
#                         Marks
# team
# Essendon                 2399
# Geelong                  2096
# Hawthorn                 2041
# Carlton                  2031
# St Kilda                 2018
# Port Adelaide            1983
# North Melbourne          1978
# Fremantle                1964
# West Coast               1958
# Melbourne                1945
# Richmond                 1921
# Greater Western Sydney   1920
# Brisbane Lions           1882
# Adelaide                 1872
# Collingwood              1872
# Sydney                   1831
# Gold Coast               1609
# Western Bulldogs         1575

# %%
seasonal1=stats[(stats['year']==2013)&(stats['round']=='R1')]
seasonal2=stats[(stats['year']==2013)&(stats['round']=='R2')]
seasonal3=stats[(stats['year']==2013)&(stats['round']=='R3')]
seasonal4=stats[(stats['year']==2013)&(stats['round']=='R4')]
seasonal5=stats[(stats['year']==2013)&(stats['round']=='R5')]
seasonal6=stats[(stats['year']==2013)&(stats['round']=='R6')]
seasonal7=stats[(stats['year']==2013)&(stats['round']=='R7')]
seasonal8=stats[(stats['year']==2013)&(stats['round']=='R8')]
seasonal9=stats[(stats['year']==2013)&(stats['round']=='R9')]
seasonal10=stats[(stats['year']==2013)&(stats['round']=='R10')]
seasonal11=stats[(stats['year']==2013)&(stats['round']=='R11')]
seasonal12=stats[(stats['year']==2013)&(stats['round']=='R12')]
seasonal13=stats[(stats['year']==2013)&(stats['round']=='R13')]
seasonal14=stats[(stats['year']==2013)&(stats['round']=='R14')]
seasonal15=stats[(stats['year']==2013)&(stats['round']=='R15')]
seasonal16=stats[(stats['year']==2013)&(stats['round']=='R16')]
seasonal17=stats[(stats['year']==2013)&(stats['round']=='R17')]
seasonal18=stats[(stats['year']==2013)&(stats['round']=='R18')]
seasonal19=stats[(stats['year']==2013)&(stats['round']=='R19')]
seasonal20=stats[(stats['year']==2013)&(stats['round']=='R20')]
seasonal21=stats[(stats['year']==2013)&(stats['round']=='R21')]
seasonal22=stats[(stats['year']==2013)&(stats['round']=='R22')]
seasonal23=stats[(stats['year']==2013)&(stats['round']=='R23')]
season2013=pd.concat([seasonal1,seasonal2,seasonal3,seasonal4,seasonal5,seasonal6,seasonal7,seasonal8,seasonal9,seasonal10,seasonal11,seasonal12,seasonal13,seasonal14,seasonal15,seasonal16,seasonal17,seasonal18,seasonal19,seasonal20,seasonal21,seasonal22,seasonal23])
table2013=season2013.pivot_table(index='team',values=['Marks'],aggfunc='sum')
table2013.sort_values(by='Marks',ascending=False)
# Out:
#                         Marks
# team
# Essendon                 2213
# Fremantle                2190
# Richmond                 2171
# Collingwood              2169
# Adelaide                 2085
# North Melbourne          2064
# St Kilda                 2037
# Geelong                  2032
# Hawthorn                 1940
# West Coast               1924
# Port Adelaide            1871
# Greater Western Sydney   1869
# Brisbane Lions           1819
# Melbourne                1816
# Carlton                  1800
# Gold Coast               1792
# Western Bulldogs         1676
# Sydney                   1560

# %%
seasonal1=stats[(stats['year']==2012)&(stats['round']=='R1')]
seasonal2=stats[(stats['year']==2012)&(stats['round']=='R2')]
seasonal3=stats[(stats['year']==2012)&(stats['round']=='R3')]
seasonal4=stats[(stats['year']==2012)&(stats['round']=='R4')]
seasonal5=stats[(stats['year']==2012)&(stats['round']=='R5')]
seasonal6=stats[(stats['year']==2012)&(stats['round']=='R6')]
seasonal7=stats[(stats['year']==2012)&(stats['round']=='R7')]
seasonal8=stats[(stats['year']==2012)&(stats['round']=='R8')]
seasonal9=stats[(stats['year']==2012)&(stats['round']=='R9')]
seasonal10=stats[(stats['year']==2012)&(stats['round']=='R10')]
seasonal11=stats[(stats['year']==2012)&(stats['round']=='R11')]
seasonal12=stats[(stats['year']==2012)&(stats['round']=='R12')]
seasonal13=stats[(stats['year']==2012)&(stats['round']=='R13')]
seasonal14=stats[(stats['year']==2012)&(stats['round']=='R14')]
seasonal15=stats[(stats['year']==2012)&(stats['round']=='R15')]
seasonal16=stats[(stats['year']==2012)&(stats['round']=='R16')]
seasonal17=stats[(stats['year']==2012)&(stats['round']=='R17')]
seasonal18=stats[(stats['year']==2012)&(stats['round']=='R18')]
seasonal19=stats[(stats['year']==2012)&(stats['round']=='R19')]
seasonal20=stats[(stats['year']==2012)&(stats['round']=='R20')]
seasonal21=stats[(stats['year']==2012)&(stats['round']=='R21')]
seasonal22=stats[(stats['year']==2012)&(stats['round']=='R22')]
seasonal23=stats[(stats['year']==2012)&(stats['round']=='R23')]
season2012=pd.concat([seasonal1,seasonal2,seasonal3,seasonal4,seasonal5,seasonal6,seasonal7,seasonal8,seasonal9,seasonal10,seasonal11,seasonal12,seasonal13,seasonal14,seasonal15,seasonal16,seasonal17,seasonal18,seasonal19,seasonal20,seasonal21,seasonal22,seasonal23])
table2012=season2012.pivot_table(index='team',values=['Marks'],aggfunc='sum')
table2012.sort_values(by='Marks',ascending=False)
# Out:
#                         Marks
# team
# St Kilda                 2099
# Fremantle                2096
# West Coast               2086
# Geelong                  2074
# Hawthorn                 2055
# Richmond                 2027
# Collingwood              2017
# Essendon                 2003
# Carlton                  1975
# Adelaide                 1969
# North Melbourne          1941
# Western Bulldogs         1919
# Brisbane Lions           1890
# Melbourne                1832
# Greater Western Sydney   1789
# Gold Coast               1787
# Port Adelaide            1777
# Sydney                   1641

# %%
season_in_total=pd.concat([table2012,table2013,table2014,table2015,table2016,table2017,table2018,table2019,table2020,table2021],axis=1,ignore_index=True)
season_in_total.columns=[2012,2013,2014,2015,2016,2017,2018,2019,2020,2021]
a=season_in_total.transpose()
a
# Out:
# team  Adelaide  Brisbane Lions  Carlton  Collingwood  Essendon  Fremantle  \
# 2012      1969            1890     1975         2017      2003       2096
# 2013      2085            1819     1800         2169      2213       2190
# 2014      1872            1882     2031         1872      2399       1964
# 2015      1926            1975     1838         1834      2104       2069
# 2016      2097            1600     1977         1968      2238       1871
# 2017      1969            2067     2288         2326      2305       1998
# 2018      2014            2184     1910         2041      2122       2016
# 2019      2080            1974     1992         2308      1919       1880
# 2020      1006            1308     1200         1238      1121       1231
# 2021      1758            2081     2098         2360      2048       1980
#
# team  Geelong  Gold Coast  Greater Western Sydney  Hawthorn  Melbourne  \
# 2012     2074        1787                    1789      2055       1832
# ...

# %%
#EF+QF,SF,PF,GF
EF=stats[(stats['year']<=2021)&(stats['round']=='EF')]
QF=stats[(stats['year']<=2021)&(stats['round']=='QF')]
SF=stats[(stats['year']<=2021)&(stats['round']=='SF')]
PF=stats[(stats['year']<=2021)&(stats['round']=='PF')]
GF=stats[(stats['year']<=2021)&(stats['round']=='GF')]

Elimination=pd.pivot_table(EF,index=['team','year'],values=['Marks'],aggfunc='sum')
Qualifying=pd.pivot_table(QF,index=['team','year'],values=['Marks'],aggfunc='sum')
Semi=pd.pivot_table(SF,index=['team','year'],values=['Marks'],aggfunc='sum')
Preliminary=pd.pivot_table(PF,index=['team','year'],values=['Marks'],aggfunc='sum')
final=pd.pivot_table(GF,index=['team','year'],values=['Marks'],aggfunc='sum')

playoffs_to_finals=pd.concat([Elimination,Qualifying,Semi,Preliminary,final],axis=1).fillna(0)
playoffs_to_finals.columns=['Elimination Final','Qualifying Final','Semi-Final','Preliminary Final','Grand Final']
final
# Out:
#                              Marks
# team                   year
# Adelaide               2017     92
# Collingwood            2018     79
# Fremantle              2013     70
# Geelong                2020     51
# Greater Western Sydney 2019    107
# Hawthorn               2012     56
#                        2013    103
#                        2014    105
#                        2015    148
# Melbourne              2021     68
# Richmond               2017     70
#                        2019    113
#                        2020     36
# Sydney                 2012     69
#                        2014     67
#                        2016     91
# West Coast             2015     56
#                        2018    104
# Western Bulldogs       2016     73
#                        2021     76

# %% [markdown]
# Number of times teams attend finals:
#
# 1 time: Adelaide, Collingwood,Fremantle, Geelong, Greater Western Sydney, Melbourne,
#
# 2 times: West Coast, Western Bulldogs
#
# 3 times: Richmond, Sydney
#
# 4 times: Hawthorn

# %%
Table=pd.read_csv('Table in total.csv')
Table
# Out:
#    Year  Adelaide  Brisbane Lions  Carlton  Collingwood  Essendon  Fremantle  \
# 0  2012      1969            1890     1975         2017      2003       2096
# 1  2013      2085            1819     1800         2169      2213       2190
# 2  2014      1872            1882     2031         1872      2399       1964
# 3  2015      1926            1975     1838         1834      2104       2069
# 4  2016      2097            1600     1977         1968      2238       1871
# 5  2017      1969            2067     2288         2326      2305       1998
# 6  2018      2014            2184     1910         2041      2122       2016
# 7  2019      2080            1974     1992         2308      1919       1880
# 8  2020      1006            1308     1200         1238      1121       1231
# 9  2021      1758            2081     2098         2360      2048       1980
#
#    Geelong  Gold Coast  Greater Western Sydney  Hawthorn  Melbourne  \
# ...

# %%
Table.describe()
# Out:
#              Year     Adelaide  Brisbane Lions      Carlton  Collingwood  \
# count    10.00000    10.000000       10.000000    10.000000    10.000000
# mean   2016.50000  1877.600000     1878.000000  1910.900000  2013.300000
# std       3.02765   323.830271      257.124267   284.738262   330.842376
# min    2012.00000  1006.000000     1308.000000  1200.000000  1238.000000
# 25%    2014.25000  1885.500000     1834.750000  1856.000000  1896.000000
# 50%    2016.50000  1969.000000     1932.000000  1976.000000  2029.000000
# 75%    2018.75000  2063.500000     2044.000000  2021.250000  2273.250000
# max    2021.00000  2097.000000     2184.000000  2288.000000  2360.000000
#
#           Essendon    Fremantle     Geelong   Gold Coast  \
# count    10.000000    10.000000    10.00000    10.000000
# mean   2047.200000  1929.500000  2001.20000  1796.500000
# std     355.773898   263.466738   231.37502   313.539383
# min    1121.000000  1231.000000  1422.00000  1140.000000
# ...

# %% [markdown]
# Melbourne is the most consistent team in overall with the lowest standard deviation value of marks: 221.567045
#
# Essendon is the most inconsistent team in overall with the highest standard deviation value of marks:355.773898
#
# However, Essendon has the best overall performance with the mean marks of 2047.2 in 10 years from 2012-2021
#
# Gold Coast has the poorest performance with the mean marks of 1796.5 in 10 years from 2012-2021

# %%
Table.plot(x='Year',y='Adelaide')
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
Table.plot(x='Year',y='Brisbane Lions')
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
Table.plot(x='Year',y='Carlton')
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
Table.plot(x='Year',y='Collingwood')
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
Table.plot(x='Year',y='Essendon')
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
Table.plot(x='Year',y='Fremantle')
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
Table.plot(x='Year',y='Geelong')
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
Table.plot(x='Year',y='Gold Coast')
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
Table.plot(x='Year',y='Greater Western Sydney')
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
Table.plot(x='Year',y='Hawthorn')
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
Table.plot(x='Year',y='Melbourne')
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
Table.plot(x='Year',y='North Melbourne')
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
Table.plot(x='Year',y='Port Adelaide')
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
Table.plot(x='Year',y='Richmond')
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
Table.plot(x='Year',y='Gold Coast')
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
Table.plot(x='Year',y='St Kilda')
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
Table.plot(x='Year',y='Sydney')
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
Table.plot(x='Year',y='West Coast')
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
Table.plot(x='Year',y='Western Bulldogs')
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
Table.plot(x='Year',y=['Essendon','Melbourne','Collingwood'],kind='bar')
plt.title('Essendon vs Melbourne')
# Out:
# Text(0.5, 1.0, 'Essendon vs Melbourne')

# %%
games[(games['homeTeam']=='Essendon')&(games['homeTeamScore']>games['awayTeamScore'])].count()
# Out:
# gameId           53
# year             53
# round            53
# date             53
# venue            53
# startTime        53
# attendance       53
# homeTeam         53
# homeTeamScore    53
# awayTeam         53
# awayTeamScore    53
# rainfall         52
# dtype: int64

# %%
games[(games['awayTeam']=='Essendon')&(games['awayTeamScore']>games['homeTeamScore'])].count()
# Out:
# gameId           46
# year             46
# round            46
# date             46
# venue            46
# startTime        46
# attendance       46
# homeTeam         46
# homeTeamScore    46
# awayTeam         46
# awayTeamScore    46
# rainfall         46
# dtype: int64

# %%
games[(games['homeTeam']=='Melbourne')&(games['homeTeamScore']>games['awayTeamScore'])].count()
# Out:
# gameId           44
# year             44
# round            44
# date             44
# venue            44
# startTime        44
# attendance       44
# homeTeam         44
# homeTeamScore    44
# awayTeam         44
# awayTeamScore    44
# rainfall         43
# dtype: int64

# %%
games[(games['awayTeam']=='Melbourne')&(games['awayTeamScore']>games['homeTeamScore'])].count()
# Out:
# gameId           45
# year             45
# round            45
# date             45
# venue            45
# startTime        45
# attendance       45
# homeTeam         45
# homeTeamScore    45
# awayTeam         45
# awayTeamScore    45
# rainfall         44
# dtype: int64
