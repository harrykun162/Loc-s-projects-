# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

import matplotlib.ticker as mticker

# %%
Melbourne = pd.read_csv('Melbourne01.csv')
Melbourne
# Out:
# C:\Users\Richard H\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (13) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#          Year  Month  Day  Hour  Min  Temp  AppTemp  DewPt  RelHum WindDir  \
# 0        2011      1    1     0    4  24.8      0.0   14.0    51.0      SE
# 1        2011      1    1     0    4  24.8      0.0   14.0    51.0      SE
# 2        2011      1    1     0   14  24.8      0.0   13.3    48.0      SE
# 3        2011      1    1     0   14  24.8      0.0   13.3    48.0      SE
# 4        2011      1    1     0   24  24.9      0.0   13.3    48.0      SE
# ...       ...    ...  ...   ...  ...   ...      ...    ...     ...     ...
# 1072130  2023      3    9     7    0  13.0     11.0    7.2    68.0       W
# 1072131  2023      3    9     7   30  13.2     11.2    7.2    67.0       W
# 1072132  2023      3    9     8    0  13.7     10.7    7.5    66.0     WNW
# 1072133  2023      3    9     8   30  14.1     11.8    7.6    65.0     WNW
# 1072134  2023      3    9     9    0  14.5     12.6    7.5    63.0     WNW
#
#          WindSpeed  WindGust  PressMSL RainTrace
# 0             11.0      13.0    1007.4         0
# 1             11.0      13.0    1007.4         0
# 2             11.0      11.0    1007.5         0
# 3             11.0      11.0    1007.5         0
# 4             11.0      13.0    1007.5         0
# ...            ...       ...       ...       ...
# 1072130       19.0      24.0    1011.5       0.0
# 1072131       17.0      19.0    1011.7       0.0
# 1072132       17.0      20.0    1011.7       0.0
# 1072133       20.0      32.0    1012.0       0.0
# 1072134       20.0      28.0    1012.0       0.0
#
# [1072135 rows x 14 columns]

# %%
Melbourne = Melbourne.drop_duplicates()
Melbourne
# Out:
#          Year  Month  Day  Hour  Min  Temp  AppTemp  DewPt  RelHum WindDir  \
# 0        2011      1    1     0    4  24.8      0.0   14.0    51.0      SE
# 2        2011      1    1     0   14  24.8      0.0   13.3    48.0      SE
# 4        2011      1    1     0   24  24.9      0.0   13.3    48.0      SE
# 6        2011      1    1     0   34  24.7      0.0   13.4    49.0      SE
# 9        2011      1    1     0   44  24.1      0.0   13.3    51.0     ESE
# ...       ...    ...  ...   ...  ...   ...      ...    ...     ...     ...
# 1072130  2023      3    9     7    0  13.0     11.0    7.2    68.0       W
# 1072131  2023      3    9     7   30  13.2     11.2    7.2    67.0       W
# 1072132  2023      3    9     8    0  13.7     10.7    7.5    66.0     WNW
# 1072133  2023      3    9     8   30  14.1     11.8    7.6    65.0     WNW
# 1072134  2023      3    9     9    0  14.5     12.6    7.5    63.0     WNW
#
#          WindSpeed  WindGust  PressMSL RainTrace
# 0             11.0      13.0    1007.4         0
# 2             11.0      11.0    1007.5         0
# 4             11.0      13.0    1007.5         0
# 6             11.0      11.0    1007.4         0
# 9              9.0       9.0    1007.3         0
# ...            ...       ...       ...       ...
# 1072130       19.0      24.0    1011.5       0.0
# 1072131       17.0      19.0    1011.7       0.0
# 1072132       17.0      20.0    1011.7       0.0
# 1072133       20.0      32.0    1012.0       0.0
# 1072134       20.0      28.0    1012.0       0.0
#
# [536577 rows x 14 columns]

# %%
Melbourne.isnull().sum()
# Out:
# Year         0
# Month        0
# Day          0
# Hour         0
# Min          0
# Temp         0
# AppTemp      0
# DewPt        0
# RelHum       0
# WindDir      0
# WindSpeed    0
# WindGust     0
# PressMSL     0
# RainTrace    0
# dtype: int64

# %%
Melbourne.WindDir.unique()
# Out:
# array(['SE', 'ESE', 'NE', 'NNE', 'ENE', 'W', 'N', 'SW', 'SSE', 'S', 'SSW',
#        'WSW', 'NW', 'WNW', 'NNW', 'E', 'CALM', '1016.6', '1016.9',
#        '1017.0', '1017.4', '1026.0', '1026.1', '1025.3', '1024.2',
#        '1029.6', '1003.3', '1008.2', '1019.0', '1015.5', '1014.2',
#        '1015.9', '1016.2', '1016.1', '1014.1', '1014.0', '1013.6',
#        '1012.7', '1013.1', '1014.4', '1014.6', '1015.6', '1015.8',
#        '1016.7', '1017.2', '1016.0', '1017.8', '1019.5', '1019.8',
#        '1019.9', '1020.4', '1021.0', '1021.2', '1021.7', '1021.9',
#        '1022.3', '1022.7', '1004.5', '1022.0', '1010.3', '1012.0',
#        '1010.8', '-'], dtype=object)

# %%
Melbourne.RainTrace.unique()
# Out:
# array([0.0, 0.6, 0.2, 1.2, 1.6, 1.8, 2.6, 3.0, 3.6, 3.8, 4.0, 4.2, 4.4,
#        4.6, 4.8, 5.0, 5.4, 5.6, 5.8, 6.0, 6.2, 6.4, 6.6, 6.8, 7.0, 0.4,
#        0.8, 1.0, 1.4, 2.2, 5.2, 8.0, 12.4, 13.2, 13.6, 13.8, 14.2, 14.6,
#        14.8, 15.2, 15.4, 2.0, 7.6, 11.4, 11.8, 12.2, 12.8, 13.0, 14.4,
#        15.0, 15.8, 16.4, 17.0, 18.2, 19.4, 20.0, 21.6, 22.2, 23.4, 24.2,
#        25.0, 25.6, 26.0, 26.6, 27.0, 27.4, 27.6, 28.0, 9.0, 10.4, 11.2,
#        16.0, 16.6, 20.4, 21.8, 22.4, 3.4, 2.8, 3.2, 2.4, 8.2, 8.4, 9.4,
#        7.8, 8.8, 7.2, 7.4, 8.6, 9.2, 9.6, 10.0, 10.2, 10.6, 10.8, 11.0,
#        17.4, 9.8, 15.6, 18.6, 20.2, 21.2, 25.8, 44.2, 44.4, 45.8, 46.0,
#        47.2, 11.6, 12.0, 12.6, 16.2, 16.8, 17.6, 18.0, 18.4, 19.0, 19.2,
#        19.6, 19.8, 20.6, 20.8, 21.0, 27.2, 29.0, 29.6, 30.0, 30.2, 30.8,
#        33.6, 34.4, 39.8, 42.6, 43.4, 43.6, 44.6, 44.8, 45.2, 45.4, 45.6,
#        46.2, 46.4, 46.6, 47.6, 48.0, 48.4, 48.8, 13.4, 17.8, 17.2, 14.0,
#        22.0, 24.0, 24.8, 25.4, 26.4, 26.8, 27.8, 28.4, 28.6, 29.8, 30.4,
#        30.6, 31.4, 31.6, 31.8, 24.6, 26.2, 28.2, 28.8, 29.4, 33.0, 33.2,
#        33.8, 34.2, 31.0, 32.8, 34.0, 34.6, 18.8, 23.0, 24.4, 25.2, 23.2,
#        23.6, 22.8, 32.6, 39.4, 40.0, 40.4, 40.8, 41.4, 42.0, 42.4, 43.0,
#        44.0, 46.8, 48.6, 21.4, 35.0, 35.2, 35.4, 35.6, 36.4, 36.6, 37.0,
#        37.2, 37.6, 38.2, 38.4, 38.8, 39.2, 40.2, 40.6, 23.8, 29.2, 22.6,
#        32.0, 32.2, 32.4, 35.8, 36.2, 36.8, 37.8, 38.0, 39.6, 41.2, 43.2,
#        43.8, 37.4, 38.6, 36.0, 39.0, 41.0, 41.8, 33.4, 47.0, 47.8, 48.2,
#        49.0, 51.4, 53.2, 53.4, 53.6, 53.8, 54.0, 54.2, 54.4, 54.6, '0.0',
#        '0.6', '0.8', '1.0', '0.2', '1.2', '1.6', '0.4', '1.4', '1.8',
#        '2.0', '2.2', '2.4', '2.6', '2.8', '5.6', '6.2', '7.0', '8.2',
#        '8.4', '8.8', '9.0', '9.2', '9.6', '9.8', '10.0', '10.2', '10.4',
#        '10.6', '10.8', '11.0', '11.2', '11.4', '11.6', '11.8', '3.2',
#        '3.0', '3.6', '4.0', '4.8', '5.2', '5.4', '5.8', '6.0', '6.4',
#        '9.4', '3.4', '3.8', '4.2', '4.4', '5.0', '6.6', '12.0', '4.6',
#        '6.8', '7.4', '7.8', '8.0', '12.4', '13.2', '14.2', '15.0', '15.6',
#        '17.2', '18.0', '18.8', '20.0', '21.0', '23.2', '24.2', '25.0',
#        '25.8', '26.2', '26.6', '26.8', '27.2', '28.0', '28.4', '28.8',
#        '29.4', '29.6', '30.2', '30.6', '31.2', '31.4', '31.8', '32.0',
#        '7.2', '12.2', '12.6', '12.8', '13.6', '13.8', '14.0', '14.4',
#        '14.6', '15.8', '16.6', '16.8', '18.4', '20.6', '20.8', '21.2',
#        '23.8', '24.8', '25.2', '25.6', '27.4', '29.0', '29.8', '30.0',
#        '6', '0', '7.6', '8.6', '17.0', '19.6', '21.4', '29.2', '30.8',
#        '33.0', '35.2', '36.6', '38.4', '39.0', '39.8', '40.4', '41.2',
#        '41.4', '41.6', '41.8', '42.0', '42.2', '42.8', '43.0', '43.2',
#        '13.0', '13.4', '15.2', '16.2', '18.2', '19.4', '20.4', '22.4',
#        '23.4', '24.0', '24.6', '28.6', '-', '15.4', '17.6', '22.0',
#        '32.2', '33.4', '34.6', '35.4', '36.8', '37.0', '37.4', '37.6',
#        '38.0', '38.2', '14.8', '16.4', '17.4', '18.6', '19.0', '19.2',
#        '19.8', '20.2', '21.6', '21.8', '22.6', '23.0', '25.4', '26.0',
#        '26.4', 34.8, 45.0, 31.2, '22.2', '16.0'], dtype=object)

# %%
Melbourne.dtypes
# Out:
# Year           int64
# Month          int64
# Day            int64
# Hour           int64
# Min            int64
# Temp         float64
# AppTemp      float64
# DewPt        float64
# RelHum       float64
# WindDir       object
# WindSpeed    float64
# WindGust     float64
# PressMSL     float64
# RainTrace     object
# dtype: object

# %%
values = ['SE', 'ESE', 'NE', 'NNE', 'ENE', 'W', 'N', 'SW', 'SSE', 'S', 'SSW','WSW', 'NW', 'WNW', 'NNW', 'E']
degrees = [135.0,112.5,45.0,22.5,67.5,270.0,0,225.0,157.5,180.0,202.5,247.5,315.0,292.5,337.5,90.0]

#drop rows that contain any value in the list
Melbourne = Melbourne[Melbourne.WindDir.isin(values) == True]
Melbourne = Melbourne.query("RainTrace != '-'")
Melbourne = Melbourne.query("WindSpeed != -9999.0")
Melbourne = Melbourne.query("WindGust != -9999.0")
Melbourne = Melbourne.query("PressMSL != -9999.0")
Melbourne = Melbourne.query("RelHum != 0.0")
Melbourne['RainTrace'] = Melbourne['RainTrace'].astype(float)
Melbourne
# Out:
#          Year  Month  Day  Hour  Min  Temp  AppTemp  DewPt  RelHum WindDir  \
# 0        2011      1    1     0    4  24.8      0.0   14.0    51.0      SE
# 2        2011      1    1     0   14  24.8      0.0   13.3    48.0      SE
# 4        2011      1    1     0   24  24.9      0.0   13.3    48.0      SE
# 6        2011      1    1     0   34  24.7      0.0   13.4    49.0      SE
# 9        2011      1    1     0   44  24.1      0.0   13.3    51.0     ESE
# ...       ...    ...  ...   ...  ...   ...      ...    ...     ...     ...
# 1072130  2023      3    9     7    0  13.0     11.0    7.2    68.0       W
# 1072131  2023      3    9     7   30  13.2     11.2    7.2    67.0       W
# 1072132  2023      3    9     8    0  13.7     10.7    7.5    66.0     WNW
# 1072133  2023      3    9     8   30  14.1     11.8    7.6    65.0     WNW
# 1072134  2023      3    9     9    0  14.5     12.6    7.5    63.0     WNW
#
#          WindSpeed  WindGust  PressMSL  RainTrace
# 0             11.0      13.0    1007.4        0.0
# 2             11.0      11.0    1007.5        0.0
# 4             11.0      13.0    1007.5        0.0
# 6             11.0      11.0    1007.4        0.0
# 9              9.0       9.0    1007.3        0.0
# ...            ...       ...       ...        ...
# 1072130       19.0      24.0    1011.5        0.0
# 1072131       17.0      19.0    1011.7        0.0
# 1072132       17.0      20.0    1011.7        0.0
# 1072133       20.0      32.0    1012.0        0.0
# 1072134       20.0      28.0    1012.0        0.0
#
# [527143 rows x 14 columns]

# %%
for i in range(len(degrees)):
    Melbourne['WindDir'] = Melbourne['WindDir'].replace(values[i], degrees[i])
    
Melbourne
# Out:
#          Year  Month  Day  Hour  Min  Temp  AppTemp  DewPt  RelHum  WindDir  \
# 0        2011      1    1     0    4  24.8      0.0   14.0    51.0    135.0
# 2        2011      1    1     0   14  24.8      0.0   13.3    48.0    135.0
# 4        2011      1    1     0   24  24.9      0.0   13.3    48.0    135.0
# 6        2011      1    1     0   34  24.7      0.0   13.4    49.0    135.0
# 9        2011      1    1     0   44  24.1      0.0   13.3    51.0    112.5
# ...       ...    ...  ...   ...  ...   ...      ...    ...     ...      ...
# 1072130  2023      3    9     7    0  13.0     11.0    7.2    68.0    270.0
# 1072131  2023      3    9     7   30  13.2     11.2    7.2    67.0    270.0
# 1072132  2023      3    9     8    0  13.7     10.7    7.5    66.0    292.5
# 1072133  2023      3    9     8   30  14.1     11.8    7.6    65.0    292.5
# 1072134  2023      3    9     9    0  14.5     12.6    7.5    63.0    292.5
#
#          WindSpeed  WindGust  PressMSL  RainTrace
# 0             11.0      13.0    1007.4        0.0
# 2             11.0      11.0    1007.5        0.0
# 4             11.0      13.0    1007.5        0.0
# 6             11.0      11.0    1007.4        0.0
# 9              9.0       9.0    1007.3        0.0
# ...            ...       ...       ...        ...
# 1072130       19.0      24.0    1011.5        0.0
# 1072131       17.0      19.0    1011.7        0.0
# 1072132       17.0      20.0    1011.7        0.0
# 1072133       20.0      32.0    1012.0        0.0
# 1072134       20.0      28.0    1012.0        0.0
#
# [527143 rows x 14 columns]

# %%
Mel_date = pd.DataFrame({'year': Melbourne['Year'],
                         'month': Melbourne['Month'],
                         'day': Melbourne['Day'],
                         'hour' : Melbourne['Hour'],
                         'minute': Melbourne['Min']})
date_time = pd.to_datetime(Mel_date[["year", "month", "day",'hour',"minute"]])

Melbourne["date_time"] = date_time
Melbourne
# Out:
#          Year  Month  Day  Hour  Min  Temp  AppTemp  DewPt  RelHum  WindDir  \
# 0        2011      1    1     0    4  24.8      0.0   14.0    51.0    135.0
# 2        2011      1    1     0   14  24.8      0.0   13.3    48.0    135.0
# 4        2011      1    1     0   24  24.9      0.0   13.3    48.0    135.0
# 6        2011      1    1     0   34  24.7      0.0   13.4    49.0    135.0
# 9        2011      1    1     0   44  24.1      0.0   13.3    51.0    112.5
# ...       ...    ...  ...   ...  ...   ...      ...    ...     ...      ...
# 1072130  2023      3    9     7    0  13.0     11.0    7.2    68.0    270.0
# 1072131  2023      3    9     7   30  13.2     11.2    7.2    67.0    270.0
# 1072132  2023      3    9     8    0  13.7     10.7    7.5    66.0    292.5
# 1072133  2023      3    9     8   30  14.1     11.8    7.6    65.0    292.5
# 1072134  2023      3    9     9    0  14.5     12.6    7.5    63.0    292.5
#
#          WindSpeed  WindGust  PressMSL  RainTrace           date_time
# 0             11.0      13.0    1007.4        0.0 2011-01-01 00:04:00
# 2             11.0      11.0    1007.5        0.0 2011-01-01 00:14:00
# 4             11.0      13.0    1007.5        0.0 2011-01-01 00:24:00
# 6             11.0      11.0    1007.4        0.0 2011-01-01 00:34:00
# 9              9.0       9.0    1007.3        0.0 2011-01-01 00:44:00
# ...            ...       ...       ...        ...                 ...
# 1072130       19.0      24.0    1011.5        0.0 2023-03-09 07:00:00
# 1072131       17.0      19.0    1011.7        0.0 2023-03-09 07:30:00
# 1072132       17.0      20.0    1011.7        0.0 2023-03-09 08:00:00
# 1072133       20.0      32.0    1012.0        0.0 2023-03-09 08:30:00
# 1072134       20.0      28.0    1012.0        0.0 2023-03-09 09:00:00
#
# [527143 rows x 15 columns]

# %%
Melbourne = Melbourne.set_index(pd.DatetimeIndex(Melbourne['date_time'])).drop(Melbourne.columns[14], axis=1)

# %%
Melbourne1 = Melbourne.resample("30T").mean().round(1)
Melbourne1
# Out:
#                        Year  Month  Day  Hour   Min  Temp  AppTemp  DewPt  \
# date_time
# 2011-01-01 00:00:00  2011.0    1.0  1.0   0.0  14.0  24.8      0.0   13.5
# 2011-01-01 00:30:00  2011.0    1.0  1.0   0.0  44.0  24.4      0.0   13.3
# 2011-01-01 01:00:00  2011.0    1.0  1.0   1.0  14.0  23.6      0.0   13.5
# 2011-01-01 01:30:00  2011.0    1.0  1.0   1.0  39.0  23.5      0.0   13.4
# 2011-01-01 02:00:00  2011.0    1.0  1.0   2.0  19.0  23.6      0.0   13.4
# ...                     ...    ...  ...   ...   ...   ...      ...    ...
# 2023-03-09 07:00:00  2023.0    3.0  9.0   7.0   0.0  13.0     11.0    7.2
# 2023-03-09 07:30:00  2023.0    3.0  9.0   7.0  30.0  13.2     11.2    7.2
# 2023-03-09 08:00:00  2023.0    3.0  9.0   8.0   0.0  13.7     10.7    7.5
# 2023-03-09 08:30:00  2023.0    3.0  9.0   8.0  30.0  14.1     11.8    7.6
# 2023-03-09 09:00:00  2023.0    3.0  9.0   9.0   0.0  14.5     12.6    7.5
#
#                      RelHum  WindDir  WindSpeed  WindGust  PressMSL  RainTrace
# date_time
# 2011-01-01 00:00:00    49.0    135.0       11.0      12.3    1007.5        0.0
# 2011-01-01 00:30:00    50.0     97.5        9.7       9.7    1007.3        0.0
# 2011-01-01 01:00:00    52.7     52.5        7.7       8.3    1007.3        0.0
# 2011-01-01 01:30:00    53.0     67.5        3.0       3.5    1007.2        0.0
# 2011-01-01 02:00:00    52.0    168.8        0.0       0.0    1007.2        0.0
# ...                     ...      ...        ...       ...       ...        ...
# 2023-03-09 07:00:00    68.0    270.0       19.0      24.0    1011.5        0.0
# 2023-03-09 07:30:00    67.0    270.0       17.0      19.0    1011.7        0.0
# 2023-03-09 08:00:00    66.0    292.5       17.0      20.0    1011.7        0.0
# 2023-03-09 08:30:00    65.0    292.5       20.0      32.0    1012.0        0.0
# 2023-03-09 09:00:00    63.0    292.5       20.0      28.0    1012.0        0.0
#
# [213619 rows x 14 columns]

# %%
Melbourne1.isna().sum()
# Out:
# Year         5819
# Month        5819
# Day          5819
# Hour         5819
# Min          5819
# Temp         5819
# AppTemp      5819
# DewPt        5819
# RelHum       5819
# WindDir      5819
# WindSpeed    5819
# WindGust     5819
# PressMSL     5819
# RainTrace    5819
# dtype: int64

# %%
Melbourne1 = Melbourne1.interpolate(method='linear')
Melbourne1
# Out:
#                        Year  Month  Day  Hour   Min  Temp  AppTemp  DewPt  \
# date_time
# 2011-01-01 00:00:00  2011.0    1.0  1.0   0.0  14.0  24.8      0.0   13.5
# 2011-01-01 00:30:00  2011.0    1.0  1.0   0.0  44.0  24.4      0.0   13.3
# 2011-01-01 01:00:00  2011.0    1.0  1.0   1.0  14.0  23.6      0.0   13.5
# 2011-01-01 01:30:00  2011.0    1.0  1.0   1.0  39.0  23.5      0.0   13.4
# 2011-01-01 02:00:00  2011.0    1.0  1.0   2.0  19.0  23.6      0.0   13.4
# ...                     ...    ...  ...   ...   ...   ...      ...    ...
# 2023-03-09 07:00:00  2023.0    3.0  9.0   7.0   0.0  13.0     11.0    7.2
# 2023-03-09 07:30:00  2023.0    3.0  9.0   7.0  30.0  13.2     11.2    7.2
# 2023-03-09 08:00:00  2023.0    3.0  9.0   8.0   0.0  13.7     10.7    7.5
# 2023-03-09 08:30:00  2023.0    3.0  9.0   8.0  30.0  14.1     11.8    7.6
# 2023-03-09 09:00:00  2023.0    3.0  9.0   9.0   0.0  14.5     12.6    7.5
#
#                      RelHum  WindDir  WindSpeed  WindGust  PressMSL  RainTrace
# date_time
# 2011-01-01 00:00:00    49.0    135.0       11.0      12.3    1007.5        0.0
# 2011-01-01 00:30:00    50.0     97.5        9.7       9.7    1007.3        0.0
# 2011-01-01 01:00:00    52.7     52.5        7.7       8.3    1007.3        0.0
# 2011-01-01 01:30:00    53.0     67.5        3.0       3.5    1007.2        0.0
# 2011-01-01 02:00:00    52.0    168.8        0.0       0.0    1007.2        0.0
# ...                     ...      ...        ...       ...       ...        ...
# 2023-03-09 07:00:00    68.0    270.0       19.0      24.0    1011.5        0.0
# 2023-03-09 07:30:00    67.0    270.0       17.0      19.0    1011.7        0.0
# 2023-03-09 08:00:00    66.0    292.5       17.0      20.0    1011.7        0.0
# 2023-03-09 08:30:00    65.0    292.5       20.0      32.0    1012.0        0.0
# 2023-03-09 09:00:00    63.0    292.5       20.0      28.0    1012.0        0.0
#
# [213619 rows x 14 columns]

# %%
Melbourne1.isna().sum()
# Out:
# Year         0
# Month        0
# Day          0
# Hour         0
# Min          0
# Temp         0
# AppTemp      0
# DewPt        0
# RelHum       0
# WindDir      0
# WindSpeed    0
# WindGust     0
# PressMSL     0
# RainTrace    0
# dtype: int64

# %% [markdown]
# ### Exploratory

# %%
def plt_correlation_matrix(corrs):
    '''Uses the seaborn heatmap to plot the correlation matrix of a pandas dataframe''' 
    # as this is a symmetric table, set up a mask so that we only plot values 
    # below the main diagonal
    mask = np.triu(np.ones_like(corrs, dtype=np.bool))
    f, ax = plt.subplots(figsize=(20, 15)) # initialise the plots and axes
    # plot the correlations as a seaborn heatmap, with a colourbar
    sns.heatmap(corrs, cmap="crest",mask=mask, center=5, annot=True, square=False, linewidths=4) 
    # do some fiddling so that the top and bottom are not obscured
    bottom, top = ax.get_ylim() 
    ax.set_ylim(bottom + 0.5, top - 0.5)
    
    
    
plt_correlation_matrix(Melbourne.corr()) # plot the correlation table

# %%
Melbourne1[(Melbourne1['Year']==2022)&(Melbourne1['Month']==6)&(Melbourne1['Day']==28)&(Melbourne1['Hour']<9)]
# Out:
#                        Year  Month   Day  Hour   Min  Temp  AppTemp  DewPt  \
# date_time
# 2022-06-28 00:00:00  2022.0    6.0  28.0   0.0   5.0   9.2      7.2    6.6
# 2022-06-28 00:30:00  2022.0    6.0  28.0   0.0  40.0   8.9      6.9    6.7
# 2022-06-28 01:00:00  2022.0    6.0  28.0   1.0  10.0   8.8      6.7    6.7
# 2022-06-28 01:30:00  2022.0    6.0  28.0   1.0  40.0   8.2      6.6    6.4
# 2022-06-28 02:00:00  2022.0    6.0  28.0   2.0  10.0   7.8      7.0    6.6
# 2022-06-28 02:30:00  2022.0    6.0  28.0   2.0  40.0   7.8      5.4    5.9
# 2022-06-28 03:00:00  2022.0    6.0  28.0   3.0  10.0   7.4      5.0    5.6
# 2022-06-28 03:30:00  2022.0    6.0  28.0   3.0  35.0   7.2      4.8    5.4
# 2022-06-28 04:00:00  2022.0    6.0  28.0   4.0  10.0   6.7      4.3    5.1
# 2022-06-28 04:30:00  2022.0    6.0  28.0   4.0  40.0   6.5      3.7    5.0
# 2022-06-28 05:00:00  2022.0    6.0  28.0   5.0  10.0   6.3      3.6    4.9
# 2022-06-28 05:30:00  2022.0    6.0  28.0   5.0  40.0   6.1      3.3    4.7
# 2022-06-28 06:00:00  2022.0    6.0  28.0   6.0  10.0   6.2      3.7    4.5
# 2022-06-28 06:30:00  2022.0    6.0  28.0   6.0  40.0   6.1      3.6    4.8
# 2022-06-28 07:00:00  2022.0    6.0  28.0   7.0  10.0   6.2      3.8    5.1
# 2022-06-28 07:30:00  2022.0    6.0  28.0   7.0  30.0   6.2      3.8    5.2
# 2022-06-28 08:00:00  2022.0    6.0  28.0   8.0   0.0   6.1      3.9    5.4
# 2022-06-28 08:30:00  2022.0    6.0  28.0   8.0  45.0   6.2      3.4    5.2
#
#                      RelHum  WindDir  WindSpeed  WindGust  PressMSL  RainTrace
# date_time
# 2022-06-28 00:00:00    83.5      0.0       15.0      15.0    1032.5        0.2
# 2022-06-28 00:30:00    86.0      0.0       11.7      13.0    1032.5        0.2
# 2022-06-28 01:00:00    86.7      0.0       12.3      13.7    1032.3        0.2
# 2022-06-28 01:30:00    88.3      0.0       15.0      16.3    1032.2        0.2
# 2022-06-28 02:00:00    92.0     22.5       13.0      15.0    1032.4        0.2
# 2022-06-28 02:30:00    88.3      7.5       15.0      16.3    1032.3        0.2
# 2022-06-28 03:00:00    88.7      7.5       17.0      17.7    1032.1        0.2
# 2022-06-28 03:30:00    88.5      0.0       21.0      23.0    1031.8        0.2
# 2022-06-28 04:00:00    89.7      0.0       18.3      19.7    1031.5        0.2
# 2022-06-28 04:30:00    90.0      0.0       19.3      20.7    1031.6        0.2
# 2022-06-28 05:00:00    91.3      0.0       19.0      20.0    1031.5        0.2
# 2022-06-28 05:30:00    91.0      0.0       19.3      19.3    1031.5        0.2
# 2022-06-28 06:00:00    88.3      0.0       19.7      22.0    1031.6        0.2
# 2022-06-28 06:30:00    91.3      0.0       19.3      21.3    1031.6        0.2
# 2022-06-28 07:00:00    92.7      0.0       18.3      19.7    1032.0        0.2
# 2022-06-28 07:30:00    93.0      0.0       17.0      17.0    1032.1        0.2
# 2022-06-28 08:00:00    95.0      0.0       19.0      20.0    1032.4        0.2
# 2022-06-28 08:30:00    93.0     11.2       20.0      23.0    1032.1        0.2

# %%
print('2022-06-28 <9am:')
tmp_df1 = Melbourne1[(Melbourne1['Year']==2023)&(Melbourne1['Month']==3)&(Melbourne1['Day']==7)\
         &(Melbourne1['Hour']<9)]
print('2022-06-27 >9am:\n'),
tmp_df2 = Melbourne1[(Melbourne1['Year']==2023)&(Melbourne1['Month']==3)&(Melbourne1['Day']==6)\
         &(Melbourne1['Hour']<9)]
# tmp_df2['RainTrace'].describe()
# tmp_df1['RainTrace'].describe()
# tmp_df = tmp_df2['RainTrace'].append(tmp_df1['RainTrace'])
# Out:
# 2022-06-28 <9am:
# 2022-06-27 >9am:

# %%
df = pd.DataFrame(np.random.random((10000,3)))
df['date'] = pd.date_range('2011-01-01 08:30:00', periods=10000, freq='D')
mask = (df['date'] > '2011-01-01') & (df['date'] <= '2023-03-07')
# print(df['date'].loc[mask])
dates=df['date'].loc[mask].values
print(dates)
# Out:
# ['2011-01-01T08:30:00.000000000' '2011-01-02T08:30:00.000000000'
#  '2011-01-03T08:30:00.000000000' ... '2023-03-04T08:30:00.000000000'
#  '2023-03-05T08:30:00.000000000' '2023-03-06T08:30:00.000000000']

# %%
Melbourne1.loc[dates]
# Out:
#                        Year  Month  Day  Hour   Min   Temp  AppTemp  DewPt  \
# date_time
# 2011-01-01 08:30:00  2011.0    1.0  1.0   8.0  44.0  17.70      0.0  12.00
# 2011-01-02 08:30:00  2011.0    1.0  2.0   8.5  17.5  16.96      0.0   9.16
# 2011-01-03 08:30:00  2011.0    1.0  3.0   8.0  49.0  15.20      0.0   4.10
# 2011-01-04 08:30:00  2011.0    1.0  4.0   8.0  44.0  14.60      0.0   9.10
# 2011-01-05 08:30:00  2011.0    1.0  5.0   8.0  49.0  17.30      0.0  11.60
# ...                     ...    ...  ...   ...   ...    ...      ...    ...
# 2023-03-02 08:30:00  2023.0    3.0  2.0   8.0  30.0  15.90     14.7  11.50
# 2023-03-03 08:30:00  2023.0    3.0  3.0   8.0  30.0  16.50     15.1  10.80
# 2023-03-04 08:30:00  2023.0    3.0  4.0   8.0  30.0  15.40     14.8  12.30
# 2023-03-05 08:30:00  2023.0    3.0  5.0   8.0  30.0  19.40     19.1  13.30
# 2023-03-06 08:30:00  2023.0    3.0  6.0   8.0  30.0  16.50     15.0  10.40
#
#                      RelHum  WindDir  WindSpeed  WindGust  PressMSL  RainTrace
# date_time
# 2011-01-01 08:30:00   68.70    202.5       15.0      17.7   1012.10        0.0
# 2011-01-02 08:30:00   59.75    198.0       22.2      27.1   1016.35        0.0
# 2011-01-03 08:30:00   47.50    168.8       25.0      29.0   1018.10        0.0
# 2011-01-04 08:30:00   69.70    187.5       17.0      19.3   1014.20        0.0
# 2011-01-05 08:30:00   69.00    213.8       21.0      26.0   1009.80        0.0
# ...                     ...      ...        ...       ...       ...        ...
# 2023-03-02 08:30:00   75.00    247.5       11.0      15.0   1014.50        0.8
# 2023-03-03 08:30:00   69.00    135.0       30.0      39.0   1018.70        0.2
# 2023-03-04 08:30:00   82.00     22.5       11.0      17.0   1013.40        0.0
# 2023-03-05 08:30:00   68.00      0.0       32.0      50.0   1003.90        0.0
# 2023-03-06 08:30:00   67.00      0.0       15.0      17.0   1004.90        5.6
#
# [4448 rows x 14 columns]

# %%
daily = Melbourne1.loc[dates].drop(columns=['Hour','Min','Temp','AppTemp','DewPt','RelHum','WindDir','WindSpeed','WindGust','PressMSL']).groupby(['Year','Month','Day']).mean().round(1)

daily = daily.reset_index(['Month','Year','Day'])

daily
# Out:
#         Year  Month  Day  RainTrace
# 0     2011.0    1.0  1.0        0.0
# 1     2011.0    1.0  2.0        0.0
# 2     2011.0    1.0  3.0        0.0
# 3     2011.0    1.0  4.0        0.0
# 4     2011.0    1.0  5.0        0.0
# ...      ...    ...  ...        ...
# 4443  2023.0    3.0  2.0        0.8
# 4444  2023.0    3.0  3.0        0.2
# 4445  2023.0    3.0  4.0        0.0
# 4446  2023.0    3.0  5.0        0.0
# 4447  2023.0    3.0  6.0        5.6
#
# [4448 rows x 4 columns]

# %%
monthly = daily.drop(columns=['Day']).groupby(['Year','Month']).sum().round(1)

monthly = monthly.reset_index(['Month','Year'])

monthly
# Out:
#        Year  Month  RainTrace
# 0    2011.0    1.0       84.1
# 1    2011.0    2.0       45.4
# 2    2011.0    3.0       30.2
# 3    2011.0    4.0       81.0
# 4    2011.0    5.0       67.5
# ..      ...    ...        ...
# 142  2022.0   11.0       73.4
# 143  2022.0   12.0       41.8
# 144  2023.0    1.0       20.2
# 145  2023.0    2.0       23.2
# 146  2023.0    3.0        9.8
#
# [147 rows x 3 columns]

# %%
Meteorology_raintrace = pd.read_csv("IDCJAC0001_086338_Data1.csv")
Meteorology_raintrace
# Out:
#     Product code  Station number  Year  Month  \
# 0     IDCJAC0001           86338  2013      7
# 1     IDCJAC0001           86338  2013      8
# 2     IDCJAC0001           86338  2013      9
# 3     IDCJAC0001           86338  2013     10
# 4     IDCJAC0001           86338  2013     11
# ..           ...             ...   ...    ...
# 111   IDCJAC0001           86338  2022     11
# 112   IDCJAC0001           86338  2022     12
# 113   IDCJAC0001           86338  2023      1
# 114   IDCJAC0001           86338  2023      2
# 115   IDCJAC0001           86338  2023      3
#
#      Monthly Precipitation Total (millimetres) Quality
# 0                                         64.4       N
# 1                                         54.2       N
# 2                                         81.8       N
# 3                                         44.6       N
# 4                                         53.0       N
# ..                                         ...     ...
# 111                                       73.8       N
# 112                                       42.4       N
# 113                                       20.2       N
# 114                                       23.6       N
# 115                                       48.8       N
#
# [116 rows x 6 columns]

# %%
merged_data = pd.merge(monthly, Meteorology_raintrace, on = ['Month','Year'])
merged_data
# Out:
#        Year  Month  RainTrace Product code  Station number  \
# 0    2013.0    7.0       60.8   IDCJAC0001           86338
# 1    2013.0    8.0       56.9   IDCJAC0001           86338
# 2    2013.0    9.0       83.6   IDCJAC0001           86338
# 3    2013.0   10.0       47.0   IDCJAC0001           86338
# 4    2013.0   11.0       54.7   IDCJAC0001           86338
# ..      ...    ...        ...          ...             ...
# 111  2022.0   11.0       73.4   IDCJAC0001           86338
# 112  2022.0   12.0       41.8   IDCJAC0001           86338
# 113  2023.0    1.0       20.2   IDCJAC0001           86338
# 114  2023.0    2.0       23.2   IDCJAC0001           86338
# 115  2023.0    3.0        9.8   IDCJAC0001           86338
#
#      Monthly Precipitation Total (millimetres) Quality
# 0                                         64.4       N
# 1                                         54.2       N
# 2                                         81.8       N
# 3                                         44.6       N
# 4                                         53.0       N
# ..                                         ...     ...
# 111                                       73.8       N
# 112                                       42.4       N
# 113                                       20.2       N
# 114                                       23.6       N
# 115                                       48.8       N
#
# [116 rows x 7 columns]

# %%
plt.plot(merged_data['Month'], merged_data['RainTrace'], label='RainTrace')
plt.plot(merged_data['Month'], merged_data['Monthly Precipitation Total (millimetres)'], 
         label='Monthly Precipitation Total (millimetres)')
plt.legend()
plt.show()

# %%
year_2013 = merged_data.loc[merged_data['Year']==2013]
year_2013
# Out:
#      Year  Month  RainTrace Product code  Station number  \
# 0  2013.0    7.0       60.8   IDCJAC0001           86338
# 1  2013.0    8.0       56.9   IDCJAC0001           86338
# 2  2013.0    9.0       83.6   IDCJAC0001           86338
# 3  2013.0   10.0       47.0   IDCJAC0001           86338
# 4  2013.0   11.0       54.7   IDCJAC0001           86338
# 5  2013.0   12.0       38.6   IDCJAC0001           86338
#
#    Monthly Precipitation Total (millimetres) Quality
# 0                                       64.4       N
# 1                                       54.2       N
# 2                                       81.8       N
# 3                                       44.6       N
# 4                                       53.0       N
# 5                                       40.6       N

# %%
plt.plot(year_2013['Month'], year_2013['RainTrace'], label='2013 RainTrace')
plt.plot(year_2013['Month'], year_2013['Monthly Precipitation Total (millimetres)'], 
         label='2013 Monthly Precipitation Total (millimetres)')
plt.legend()
plt.show()

# %%
year_2014 = merged_data.loc[merged_data['Year']==2014]
year_2014
# Out:
#       Year  Month  RainTrace Product code  Station number  \
# 6   2014.0    1.0       13.6   IDCJAC0001           86338
# 7   2014.0    2.0       23.1   IDCJAC0001           86338
# 8   2014.0    3.0       23.4   IDCJAC0001           86338
# 9   2014.0    4.0       69.0   IDCJAC0001           86338
# 10  2014.0    5.0       33.2   IDCJAC0001           86338
# 11  2014.0    6.0       49.1   IDCJAC0001           86338
# 12  2014.0    7.0       19.2   IDCJAC0001           86338
# 13  2014.0    8.0       37.9   IDCJAC0001           86338
# 14  2014.0    9.0       31.7   IDCJAC0001           86338
# 15  2014.0   10.0       50.4   IDCJAC0001           86338
# 16  2014.0   11.0       62.3   IDCJAC0001           86338
# 17  2014.0   12.0       34.3   IDCJAC0001           86338
#
#     Monthly Precipitation Total (millimetres) Quality
# 6                                        13.4       N
# 7                                        22.4       N
# 8                                        21.8       N
# 9                                        68.0       N
# 10                                       33.8       N
# 11                                       48.8       N
# 12                                       20.2       N
# 13                                       31.4       N
# 14                                       31.2       N
# 15                                       45.8       N
# 16                                       58.2       N
# 17                                       37.0       N

# %%
plt.plot(year_2014['Month'], year_2014['RainTrace'], label='2014 RainTrace')
plt.plot(year_2014['Month'], year_2014['Monthly Precipitation Total (millimetres)'], 
         label='2014 Monthly Precipitation Total (millimetres)')
plt.legend()
plt.show()

# %%
year_2015 = merged_data.loc[merged_data['Year']==2015]
year_2015
# Out:
#       Year  Month  RainTrace Product code  Station number  \
# 18  2015.0    1.0       47.5   IDCJAC0001           86338
# 19  2015.0    2.0       37.2   IDCJAC0001           86338
# 20  2015.0    3.0       23.0   IDCJAC0001           86338
# 21  2015.0    4.0       28.5   IDCJAC0001           86338
# 22  2015.0    5.0       37.5   IDCJAC0001           86338
# 23  2015.0    6.0       19.5   IDCJAC0001           86338
# 24  2015.0    7.0       57.3   IDCJAC0001           86338
# 25  2015.0    8.0       38.0   IDCJAC0001           86338
# 26  2015.0    9.0       28.4   IDCJAC0001           86338
# 27  2015.0   10.0       12.1   IDCJAC0001           86338
# 28  2015.0   11.0       40.5   IDCJAC0001           86338
# 29  2015.0   12.0       45.8   IDCJAC0001           86338
#
#     Monthly Precipitation Total (millimetres) Quality
# 18                                       47.4       N
# 19                                       37.8       N
# 20                                       23.0       N
# 21                                       36.8       N
# 22                                       37.6       N
# 23                                       27.8       N
# 24                                       58.0       N
# 25                                       38.2       N
# 26                                       30.6       N
# 27                                       12.2       N
# 28                                       43.0       N
# 29                                       46.8       N

# %%
plt.plot(year_2015['Month'], year_2015['RainTrace'], label='2015 RainTrace')
plt.plot(year_2015['Month'], year_2015['Monthly Precipitation Total (millimetres)'], 
         label='2015 Monthly Precipitation Total (millimetres)')
plt.legend()
plt.show()

# %%
year_2016 = merged_data.loc[merged_data['Year']==2016]
year_2016
# Out:
#       Year  Month  RainTrace Product code  Station number  \
# 30  2016.0    1.0       47.2   IDCJAC0001           86338
# 31  2016.0    2.0        7.2   IDCJAC0001           86338
# 32  2016.0    3.0       28.2   IDCJAC0001           86338
# 33  2016.0    4.0       47.8   IDCJAC0001           86338
# 34  2016.0    5.0       55.8   IDCJAC0001           86338
# 35  2016.0    6.0       50.0   IDCJAC0001           86338
# 36  2016.0    7.0       63.2   IDCJAC0001           86338
# 37  2016.0    8.0       60.9   IDCJAC0001           86338
# 38  2016.0    9.0       85.8   IDCJAC0001           86338
# 39  2016.0   10.0       62.2   IDCJAC0001           86338
# 40  2016.0   11.0       31.2   IDCJAC0001           86338
# 41  2016.0   12.0       38.1   IDCJAC0001           86338
#
#     Monthly Precipitation Total (millimetres) Quality
# 30                                       48.0       Y
# 31                                        9.0       N
# 32                                       35.6       Y
# 33                                       48.6       N
# 34                                       57.0       N
# 35                                       54.4       Y
# 36                                       64.2       N
# 37                                       61.2       N
# 38                                       87.2       N
# 39                                       63.4       Y
# 40                                       31.4       N
# 41                                       39.6       N

# %%
plt.plot(year_2016['Month'], year_2016['RainTrace'], label='2016 RainTrace')
plt.plot(year_2016['Month'], year_2016['Monthly Precipitation Total (millimetres)'], 
         label='2016 Monthly Precipitation Total (millimetres)')
plt.legend()
plt.show()

# %%
year_2017 = merged_data.loc[merged_data['Year']==2017]
year_2017
# Out:
#       Year  Month  RainTrace Product code  Station number  \
# 42  2017.0    1.0       31.3   IDCJAC0001           86338
# 43  2017.0    2.0       40.2   IDCJAC0001           86338
# 44  2017.0    3.0       26.2   IDCJAC0001           86338
# 45  2017.0    4.0      122.3   IDCJAC0001           86338
# 46  2017.0    5.0       24.8   IDCJAC0001           86338
# 47  2017.0    6.0       16.8   IDCJAC0001           86338
# 48  2017.0    7.0       29.5   IDCJAC0001           86338
# 49  2017.0    8.0       53.1   IDCJAC0001           86338
# 50  2017.0    9.0       39.3   IDCJAC0001           86338
# 51  2017.0   10.0       40.4   IDCJAC0001           86338
# 52  2017.0   11.0       45.6   IDCJAC0001           86338
# 53  2017.0   12.0      127.7   IDCJAC0001           86338
#
#     Monthly Precipitation Total (millimetres) Quality
# 42                                       31.6       N
# 43                                       40.2       N
# 44                                       26.4       N
# 45                                      123.4       N
# 46                                       25.0       N
# 47                                       16.8       N
# 48                                       30.4       N
# 49                                       53.8       N
# 50                                       39.6       N
# 51                                       40.4       N
# 52                                       46.0       N
# 53                                      128.4       N

# %%
plt.plot(year_2017['Month'], year_2017['RainTrace'], label='2017 RainTrace')
plt.plot(year_2017['Month'], year_2017['Monthly Precipitation Total (millimetres)'], 
         label='2017 Monthly Precipitation Total (millimetres)')
plt.legend()
plt.show()

# %%
year_2018 = merged_data.loc[merged_data['Year']==2018]
year_2018
# Out:
#       Year  Month  RainTrace Product code  Station number  \
# 54  2018.0    1.0       65.2   IDCJAC0001           86338
# 55  2018.0    2.0        1.6   IDCJAC0001           86338
# 56  2018.0    3.0       23.0   IDCJAC0001           86338
# 57  2018.0    4.0       16.4   IDCJAC0001           86338
# 58  2018.0    5.0       65.6   IDCJAC0001           86338
# 59  2018.0    6.0       43.0   IDCJAC0001           86338
# 60  2018.0    7.0       19.2   IDCJAC0001           86338
# 61  2018.0    8.0       42.4   IDCJAC0001           86338
# 62  2018.0    9.0       16.2   IDCJAC0001           86338
# 63  2018.0   11.0       97.7   IDCJAC0001           86338
# 64  2018.0   12.0      103.5   IDCJAC0001           86338
#
#     Monthly Precipitation Total (millimetres) Quality
# 54                                       65.4       N
# 55                                        1.6       N
# 56                                       23.0       N
# 57                                       16.4       N
# 58                                       65.6       N
# 59                                       43.2       N
# 60                                       19.4       N
# 61                                       42.8       N
# 62                                       16.4       N
# 63                                       97.8       N
# 64                                      104.8       N

# %%
plt.plot(year_2018['Month'], year_2018['RainTrace'], label='2018 RainTrace')
plt.plot(year_2018['Month'], year_2018['Monthly Precipitation Total (millimetres)'], 
         label='2018 Monthly Precipitation Total (millimetres)')
plt.legend()
plt.show()

# %%
year_2019 = merged_data.loc[merged_data['Year']==2019]
year_2019
# Out:
#       Year  Month  RainTrace Product code  Station number  \
# 65  2019.0    1.0       11.2   IDCJAC0001           86338
# 66  2019.0    2.0       18.8   IDCJAC0001           86338
# 67  2019.0    3.0       11.9   IDCJAC0001           86338
# 68  2019.0    4.0        7.0   IDCJAC0001           86338
# 69  2019.0    5.0       53.2   IDCJAC0001           86338
# 70  2019.0    6.0       49.1   IDCJAC0001           86338
# 71  2019.0    7.0       44.6   IDCJAC0001           86338
# 72  2019.0    8.0       50.1   IDCJAC0001           86338
# 73  2019.0    9.0       40.6   IDCJAC0001           86338
# 74  2019.0   10.0       23.5   IDCJAC0001           86338
# 75  2019.0   11.0       54.4   IDCJAC0001           86338
# 76  2019.0   12.0        6.2   IDCJAC0001           86338
#
#     Monthly Precipitation Total (millimetres) Quality
# 65                                       11.2       N
# 66                                       18.6       Y
# 67                                       12.0       N
# 68                                        7.2       N
# 69                                       53.4       N
# 70                                       49.8       N
# 71                                       45.2       N
# 72                                       51.4       N
# 73                                       41.0       N
# 74                                       24.0       Y
# 75                                       54.4       N
# 76                                        6.2       N

# %%
plt.plot(year_2019['Month'], year_2019['RainTrace'], label='2019 RainTrace')
plt.plot(year_2019['Month'], year_2019['Monthly Precipitation Total (millimetres)'], 
         label='2019 Monthly Precipitation Total (millimetres)')
plt.legend()
plt.show()

# %%
year_2020 = merged_data.loc[merged_data['Year']==2020]
year_2020
# Out:
#       Year  Month  RainTrace Product code  Station number  \
# 77  2020.0    1.0      114.3   IDCJAC0001           86338
# 78  2020.0    2.0       75.5   IDCJAC0001           86338
# 79  2020.0    3.0       71.0   IDCJAC0001           86338
# 80  2020.0    4.0      133.9   IDCJAC0001           86338
# 81  2020.0    5.0       64.3   IDCJAC0001           86338
# 82  2020.0    6.0       28.6   IDCJAC0001           86338
# 83  2020.0    7.0       29.2   IDCJAC0001           86338
# 84  2020.0    8.0       60.9   IDCJAC0001           86338
# 85  2020.0    9.0       33.5   IDCJAC0001           86338
# 86  2020.0   10.0       72.6   IDCJAC0001           86338
# 87  2020.0   11.0       33.6   IDCJAC0001           86338
# 88  2020.0   12.0       42.0   IDCJAC0001           86338
#
#     Monthly Precipitation Total (millimetres) Quality
# 77                                      115.2       N
# 78                                       76.2       N
# 79                                       71.0       N
# 80                                      138.4       Y
# 81                                       66.8       N
# 82                                       29.0       Y
# 83                                       30.0       Y
# 84                                       61.6       N
# 85                                       33.6       N
# 86                                       74.2       N
# 87                                       48.8       N
# 88                                       42.0       N

# %%
plt.plot(year_2020['Month'], year_2020['RainTrace'], label='2020 RainTrace')
plt.plot(year_2020['Month'], year_2020['Monthly Precipitation Total (millimetres)'], 
         label='2020 Monthly Precipitation Total (millimetres)')
plt.legend()
plt.show()

# %%
year_2021 = merged_data.loc[merged_data['Year']==2021]
year_2021
# Out:
#        Year  Month  RainTrace Product code  Station number  \
# 89   2021.0    1.0       86.4   IDCJAC0001           86338
# 90   2021.0    2.0        9.2   IDCJAC0001           86338
# 91   2021.0    3.0       52.2   IDCJAC0001           86338
# 92   2021.0    4.0       36.4   IDCJAC0001           86338
# 93   2021.0    5.0       65.6   IDCJAC0001           86338
# 94   2021.0    6.0       42.6   IDCJAC0001           86338
# 95   2021.0    7.0       30.6   IDCJAC0001           86338
# 96   2021.0    8.0       49.6   IDCJAC0001           86338
# 97   2021.0    9.0       68.2   IDCJAC0001           86338
# 98   2021.0   10.0      110.1   IDCJAC0001           86338
# 99   2021.0   11.0       96.0   IDCJAC0001           86338
# 100  2021.0   12.0       22.6   IDCJAC0001           86338
#
#      Monthly Precipitation Total (millimetres) Quality
# 89                                        88.0       Y
# 90                                         9.2       Y
# 91                                        54.8       N
# 92                                        37.0       N
# 93                                        66.4       N
# 94                                        43.8       N
# 95                                        31.2       N
# 96                                        49.6       Y
# 97                                        68.6       N
# 98                                       110.4       N
# 99                                        96.6       N
# 100                                       27.0       N

# %%
plt.plot(year_2021['Month'], year_2021['RainTrace'], label='2021 RainTrace')
plt.plot(year_2021['Month'], year_2021['Monthly Precipitation Total (millimetres)'], 
         label='2021 Monthly Precipitation Total (millimetres)')
plt.legend()
plt.show()

# %%
year_2022 = merged_data.loc[merged_data['Year']==2022]
year_2022
# Out:
#        Year  Month  RainTrace Product code  Station number  \
# 101  2022.0    1.0       79.5   IDCJAC0001           86338
# 102  2022.0    2.0        6.8   IDCJAC0001           86338
# 103  2022.0    3.0       54.0   IDCJAC0001           86338
# 104  2022.0    4.0       72.5   IDCJAC0001           86338
# 105  2022.0    5.0       24.2   IDCJAC0001           86338
# 106  2022.0    6.0       52.1   IDCJAC0001           86338
# 107  2022.0    7.0       35.3   IDCJAC0001           86338
# 108  2022.0    8.0       59.5   IDCJAC0001           86338
# 109  2022.0    9.0       48.6   IDCJAC0001           86338
# 110  2022.0   10.0      144.4   IDCJAC0001           86338
# 111  2022.0   11.0       73.4   IDCJAC0001           86338
# 112  2022.0   12.0       41.8   IDCJAC0001           86338
#
#      Monthly Precipitation Total (millimetres) Quality
# 101                                       79.6       N
# 102                                        6.8       N
# 103                                       54.2       Y
# 104                                       72.6       N
# 105                                       24.2       N
# 106                                       52.4       N
# 107                                       36.2       N
# 108                                       59.4       Y
# 109                                       48.8       N
# 110                                      149.0       N
# 111                                       73.8       N
# 112                                       42.4       N

# %%
plt.plot(year_2022['Month'], year_2022['RainTrace'], label='2222 RainTrace')
plt.plot(year_2022['Month'], year_2022['Monthly Precipitation Total (millimetres)'], 
         label='2222 Monthly Precipitation Total (millimetres)')
plt.legend()
plt.show()

# %%
year_2023 = merged_data.loc[merged_data['Year']==2023]
year_2023
# Out:
#        Year  Month  RainTrace Product code  Station number  \
# 113  2023.0    1.0       20.2   IDCJAC0001           86338
# 114  2023.0    2.0       23.2   IDCJAC0001           86338
# 115  2023.0    3.0        9.8   IDCJAC0001           86338
#
#      Monthly Precipitation Total (millimetres) Quality
# 113                                       20.2       N
# 114                                       23.6       N
# 115                                       48.8       N

# %%
plt.plot(year_2023['Month'], year_2023['RainTrace'], label='2023 RainTrace')
plt.plot(year_2023['Month'], year_2023['Monthly Precipitation Total (millimetres)'], 
         label='2023 Monthly Precipitation Total (millimetres)')
plt.legend()
plt.show()

# %%
daily = Melbourne1.drop(['Hour','Min','AppTemp','DewPt','RelHum','WindDir','WindSpeed','WindGust','PressMSL','RainTrace'],axis=1).groupby(['Year','Month','Day']).max()
daily = daily.reset_index(['Year','Month','Day'])
daily
# Out:
#         Year  Month  Day   Temp
# 0     2011.0    1.0  1.0  24.80
# 1     2011.0    1.0  2.0  20.80
# 2     2011.0    1.0  3.0  20.00
# 3     2011.0    1.0  4.0  20.80
# 4     2011.0    1.0  5.0  21.20
# ...      ...    ...  ...    ...
# 6064  2023.0    3.0  5.5  20.75
# 6065  2023.0    3.0  6.0  25.10
# 6066  2023.0    3.0  7.0  23.00
# 6067  2023.0    3.0  8.0  19.00
# 6068  2023.0    3.0  9.0  14.50
#
# [6069 rows x 4 columns]

# %%
monthly = daily.drop(columns=['Day']).groupby(['Year','Month']).mean().round(1)

monthly = monthly.reset_index(['Month','Year'])

monthly
# Out:
#        Year  Month  Temp
# 0    2011.0    1.0  24.4
# 1    2011.0    2.0  19.0
# 2    2011.0    3.0  20.5
# 3    2011.0    4.0  19.1
# 4    2011.0    5.0  15.8
# ..      ...    ...   ...
# 176  2022.0   11.0  18.5
# 177  2022.0   12.0  22.8
# 178  2023.0    1.0  25.4
# 179  2023.0    2.0  22.2
# 180  2023.0    3.0  22.5
#
# [181 rows x 3 columns]

# %%
Meteorology_tem = pd.read_csv("IDCJAC0002_086338_Data1.csv")
Meteorology_tem
# Out:
#     Product code  Bureau of Meteorology station number  Year  Month  \
# 0     IDCJAC0002                                 86338  2013      6
# 1     IDCJAC0002                                 86338  2013      7
# 2     IDCJAC0002                                 86338  2013      8
# 3     IDCJAC0002                                 86338  2013      9
# 4     IDCJAC0002                                 86338  2013     10
# ..           ...                                   ...   ...    ...
# 114   IDCJAC0002                                 86338  2022     12
# 115   IDCJAC0002                                 86338  2023      1
# 116   IDCJAC0002                                 86338  2023      2
# 117   IDCJAC0002                                 86338  2023      3
# 118   IDCJAC0002                                 86338  2023      4
#
#      Mean maximum temperature (°C) Quality
# 0                             14.9       Y
# 1                             15.7       Y
# 2                             16.3       Y
# 3                             19.5       Y
# 4                             19.1       Y
# ..                             ...     ...
# 114                           23.9       Y
# 115                           26.1       Y
# 116                           25.0       Y
# 117                           23.0       Y
# 118                           20.2       Y
#
# [119 rows x 6 columns]

# %%
merged_data = pd.merge(monthly,Meteorology_tem, on = ['Month','Year'])
merged_data
# Out:
# C:\Users\Richard H\anaconda3\lib\site-packages\pandas\core\reshape\merge.py:1113: UserWarning: You are merging on int and float columns where the float values are not equal to their int representation
#   warnings.warn(
#        Year  Month  Temp Product code  Bureau of Meteorology station number  \
# 0    2013.0    6.0  14.7   IDCJAC0002                                 86338
# 1    2013.0    7.0  14.9   IDCJAC0002                                 86338
# 2    2013.0    8.0  15.5   IDCJAC0002                                 86338
# 3    2013.0    9.0  19.4   IDCJAC0002                                 86338
# 4    2013.0   10.0  18.5   IDCJAC0002                                 86338
# ..      ...    ...   ...          ...                                   ...
# 113  2022.0   11.0  18.5   IDCJAC0002                                 86338
# 114  2022.0   12.0  22.8   IDCJAC0002                                 86338
# 115  2023.0    1.0  25.4   IDCJAC0002                                 86338
# 116  2023.0    2.0  22.2   IDCJAC0002                                 86338
# 117  2023.0    3.0  22.5   IDCJAC0002                                 86338
#
#      Mean maximum temperature (°C) Quality
# 0                             14.9       Y
# 1                             15.7       Y
# 2                             16.3       Y
# 3                             19.5       Y
# 4                             19.1       Y
# ..                             ...     ...
# 113                           20.2       Y
# 114                           23.9       Y
# 115                           26.1       Y
# 116                           25.0       Y
# 117                           23.0       Y
#
# [118 rows x 7 columns]

# %%
plt.plot(merged_data['Month'], merged_data['Temp'], label='Temp')
plt.plot(merged_data['Month'], merged_data['Mean maximum temperature (°C)'], 
         label='Mean maximum temperature (°C)')
plt.legend()
plt.show()

# %%
year_2013 = merged_data.loc[merged_data['Year']==2013]
year_2013
# Out:
#      Year  Month  Temp Product code  Bureau of Meteorology station number  \
# 0  2013.0    6.0  14.7   IDCJAC0002                                 86338
# 1  2013.0    7.0  14.9   IDCJAC0002                                 86338
# 2  2013.0    8.0  15.5   IDCJAC0002                                 86338
# 3  2013.0    9.0  19.4   IDCJAC0002                                 86338
# 4  2013.0   10.0  18.5   IDCJAC0002                                 86338
# 5  2013.0   11.0  21.2   IDCJAC0002                                 86338
# 6  2013.0   12.0  24.1   IDCJAC0002                                 86338
#
#    Mean maximum temperature (°C) Quality
# 0                           14.9       Y
# 1                           15.7       Y
# 2                           16.3       Y
# 3                           19.5       Y
# 4                           19.1       Y
# 5                           20.8       Y
# 6                           23.7       Y

# %%
plt.plot(year_2013['Month'], year_2013['Temp'], label='2013 RainTrace')
plt.plot(year_2013['Month'], year_2013['Mean maximum temperature (°C)'], 
         label='2013 Mean maximum temperature (°C)')
plt.legend()
plt.show()

# %%
year_2014 = merged_data.loc[merged_data['Year']==2014]
year_2014
# Out:
#       Year  Month  Temp Product code  Bureau of Meteorology station number  \
# 7   2014.0    1.0  27.9   IDCJAC0002                                 86338
# 8   2014.0    2.0  27.3   IDCJAC0002                                 86338
# 9   2014.0    3.0  24.9   IDCJAC0002                                 86338
# 10  2014.0    4.0  20.8   IDCJAC0002                                 86338
# 11  2014.0    5.0  18.8   IDCJAC0002                                 86338
# 12  2014.0    6.0  15.2   IDCJAC0002                                 86338
# 13  2014.0    7.0  14.3   IDCJAC0002                                 86338
# 14  2014.0    8.0  14.6   IDCJAC0002                                 86338
# 15  2014.0    9.0  18.5   IDCJAC0002                                 86338
# 16  2014.0   10.0  21.3   IDCJAC0002                                 86338
# 17  2014.0   11.0  23.4   IDCJAC0002                                 86338
# 18  2014.0   12.0  24.4   IDCJAC0002                                 86338
#
#     Mean maximum temperature (°C) Quality
# 7                            27.3       Y
# 8                            27.1       Y
# 9                            24.4       Y
# 10                           20.6       Y
# 11                           19.0       Y
# 12                           15.4       Y
# 13                           14.5       Y
# 14                           15.4       Y
# 15                           18.5       Y
# 16                           21.7       Y
# 17                           22.7       Y
# 18                           23.9       Y

# %%
plt.plot(year_2014['Month'], year_2014['Temp'], label='2014 RainTrace')
plt.plot(year_2014['Month'], year_2014['Mean maximum temperature (°C)'], 
         label='2014 Mean maximum temperature (°C)')
plt.legend()
plt.show()

# %%
year_2015 = merged_data.loc[merged_data['Year']==2015]
year_2015
# Out:
#       Year  Month  Temp Product code  Bureau of Meteorology station number  \
# 19  2015.0    1.0  25.3   IDCJAC0002                                 86338
# 20  2015.0    2.0  26.1   IDCJAC0002                                 86338
# 21  2015.0    3.0  21.4   IDCJAC0002                                 86338
# 22  2015.0    4.0  18.7   IDCJAC0002                                 86338
# 23  2015.0    5.0  16.7   IDCJAC0002                                 86338
# 24  2015.0    6.0  13.6   IDCJAC0002                                 86338
# 25  2015.0    7.0  11.2   IDCJAC0002                                 86338
# 26  2015.0    8.0  13.2   IDCJAC0002                                 86338
# 27  2015.0    9.0  15.6   IDCJAC0002                                 86338
# 28  2015.0   10.0  22.8   IDCJAC0002                                 86338
# 29  2015.0   11.0  22.4   IDCJAC0002                                 86338
# 30  2015.0   12.0  27.0   IDCJAC0002                                 86338
#
#     Mean maximum temperature (°C) Quality
# 19                           25.9       Y
# 20                           26.4       Y
# 21                           22.7       Y
# 22                           19.2       Y
# 23                           17.1       Y
# 24                           14.4       Y
# 25                           13.3       Y
# 26                           13.8       Y
# 27                           17.3       Y
# 28                           24.3       Y
# 29                           22.7       Y
# 30                           27.5       Y

# %%
plt.plot(year_2015['Month'], year_2015['Temp'], label='2015 RainTrace')
plt.plot(year_2015['Month'], year_2015['Mean maximum temperature (°C)'], 
         label='2015 Mean maximum temperature (°C)')
plt.legend()
plt.show()

# %%
year_2016 = merged_data.loc[merged_data['Year']==2016]
year_2016
# Out:
#       Year  Month  Temp Product code  Bureau of Meteorology station number  \
# 31  2016.0    1.0  24.9   IDCJAC0002                                 86338
# 32  2016.0    2.0  23.9   IDCJAC0002                                 86338
# 33  2016.0    3.0  23.1   IDCJAC0002                                 86338
# 34  2016.0    4.0  22.2   IDCJAC0002                                 86338
# 35  2016.0    5.0  17.7   IDCJAC0002                                 86338
# 36  2016.0    6.0  13.5   IDCJAC0002                                 86338
# 37  2016.0    7.0  13.8   IDCJAC0002                                 86338
# 38  2016.0    8.0  15.0   IDCJAC0002                                 86338
# 39  2016.0    9.0  16.5   IDCJAC0002                                 86338
# 40  2016.0   10.0  18.2   IDCJAC0002                                 86338
# 41  2016.0   11.0  20.6   IDCJAC0002                                 86338
# 42  2016.0   12.0  23.7   IDCJAC0002                                 86338
#
#     Mean maximum temperature (°C) Quality
# 31                           26.0       Y
# 32                           25.1       Y
# 33                           24.9       Y
# 34                           22.4       Y
# 35                           18.6       Y
# 36                           14.2       Y
# 37                           14.6       Y
# 38                           15.9       Y
# 39                           16.7       Y
# 40                           19.3       Y
# 41                           20.8       Y
# 42                           25.5       Y

# %%
plt.plot(year_2016['Month'], year_2016['Temp'], label='2016 RainTrace')
plt.plot(year_2016['Month'], year_2016['Mean maximum temperature (°C)'], 
         label='2016 Mean maximum temperature (°C)')
plt.legend()
plt.show()

# %%
year_2017 = merged_data.loc[merged_data['Year']==2017]
year_2017
# Out:
#       Year  Month  Temp Product code  Bureau of Meteorology station number  \
# 43  2017.0    1.0  25.9   IDCJAC0002                                 86338
# 44  2017.0    2.0  23.8   IDCJAC0002                                 86338
# 45  2017.0    3.0  25.7   IDCJAC0002                                 86338
# 46  2017.0    4.0  19.1   IDCJAC0002                                 86338
# 47  2017.0    5.0  16.6   IDCJAC0002                                 86338
# 48  2017.0    6.0  13.4   IDCJAC0002                                 86338
# 49  2017.0    7.0  13.7   IDCJAC0002                                 86338
# 50  2017.0    8.0  13.8   IDCJAC0002                                 86338
# 51  2017.0    9.0  17.0   IDCJAC0002                                 86338
# 52  2017.0   10.0  19.3   IDCJAC0002                                 86338
# 53  2017.0   11.0  24.3   IDCJAC0002                                 86338
# 54  2017.0   12.0  24.6   IDCJAC0002                                 86338
#
#     Mean maximum temperature (°C) Quality
# 43                           26.5       Y
# 44                           25.9       Y
# 45                           26.9       Y
# 46                           20.8       Y
# 47                           17.2       Y
# 48                           14.9       Y
# 49                           14.5       Y
# 50                           14.8       Y
# 51                           17.8       Y
# 52                           20.7       Y
# 53                           25.9       Y
# 54                           25.0       Y

# %%
plt.plot(year_2017['Month'], year_2017['Temp'], label='2017 RainTrace')
plt.plot(year_2017['Month'], year_2017['Mean maximum temperature (°C)'], 
         label='2017 Mean maximum temperature (°C)')
plt.legend()
plt.show()

# %%
year_2018 = merged_data.loc[merged_data['Year']==2018]
year_2018
# Out:
#       Year  Month  Temp Product code  Bureau of Meteorology station number  \
# 55  2018.0    1.0  26.4   IDCJAC0002                                 86338
# 56  2018.0    2.0  25.8   IDCJAC0002                                 86338
# 57  2018.0    3.0  24.5   IDCJAC0002                                 86338
# 58  2018.0    4.0  19.2   IDCJAC0002                                 86338
# 59  2018.0    5.0  17.0   IDCJAC0002                                 86338
# 60  2018.0    6.0  12.3   IDCJAC0002                                 86338
# 61  2018.0    7.0  14.4   IDCJAC0002                                 86338
# 62  2018.0    8.0  14.5   IDCJAC0002                                 86338
# 63  2018.0    9.0  16.7   IDCJAC0002                                 86338
# 64  2018.0   10.0  20.7   IDCJAC0002                                 86338
# 65  2018.0   11.0  20.9   IDCJAC0002                                 86338
# 66  2018.0   12.0  25.0   IDCJAC0002                                 86338
#
#     Mean maximum temperature (°C) Quality
# 55                           27.2       Y
# 56                           27.0       Y
# 57                           24.9       Y
# 58                           21.8       Y
# 59                           17.6       Y
# 60                           14.3       Y
# 61                           14.8       Y
# 62                           15.1       Y
# 63                           17.2       Y
# 64                           21.4       Y
# 65                           22.0       Y
# 66                           25.7       Y

# %%
plt.plot(year_2018['Month'], year_2018['Temp'], label='2018 RainTrace')
plt.plot(year_2018['Month'], year_2018['Mean maximum temperature (°C)'], 
         label='2018 Mean maximum temperature (°C)')
plt.legend()
plt.show()

# %%
year_2019 = merged_data.loc[merged_data['Year']==2019]
year_2019
# Out:
#       Year  Month  Temp Product code  Bureau of Meteorology station number  \
# 67  2019.0    1.0  27.0   IDCJAC0002                                 86338
# 68  2019.0    2.0  25.4   IDCJAC0002                                 86338
# 69  2019.0    3.0  24.0   IDCJAC0002                                 86338
# 70  2019.0    4.0  21.4   IDCJAC0002                                 86338
# 71  2019.0    5.0  17.1   IDCJAC0002                                 86338
# 72  2019.0    6.0  13.4   IDCJAC0002                                 86338
# 73  2019.0    7.0  14.5   IDCJAC0002                                 86338
# 74  2019.0    8.0  13.7   IDCJAC0002                                 86338
# 75  2019.0    9.0  17.1   IDCJAC0002                                 86338
# 76  2019.0   10.0  20.0   IDCJAC0002                                 86338
# 77  2019.0   11.0  20.9   IDCJAC0002                                 86338
# 78  2019.0   12.0  22.9   IDCJAC0002                                 86338
#
#     Mean maximum temperature (°C) Quality
# 67                           28.4       Y
# 68                           26.0       Y
# 69                           24.8       Y
# 70                           22.0       Y
# 71                           17.8       Y
# 72                           15.5       Y
# 73                           15.0       Y
# 74                           14.5       Y
# 75                           17.8       Y
# 76                           21.3       Y
# 77                           21.8       Y
# 78                           24.6       Y

# %%
plt.plot(year_2019['Month'], year_2019['Temp'], label='2019 RainTrace')
plt.plot(year_2019['Month'], year_2019['Mean maximum temperature (°C)'], 
         label='2019 Mean maximum temperature (°C)')
plt.legend()
plt.show()

# %%
year_2020 = merged_data.loc[merged_data['Year']==2020]
year_2020
# Out:
#       Year  Month  Temp Product code  Bureau of Meteorology station number  \
# 79  2020.0    1.0  25.7   IDCJAC0002                                 86338
# 80  2020.0    2.0  23.1   IDCJAC0002                                 86338
# 81  2020.0    3.0  21.6   IDCJAC0002                                 86338
# 82  2020.0    4.0  18.7   IDCJAC0002                                 86338
# 83  2020.0    5.0  16.1   IDCJAC0002                                 86338
# 84  2020.0    6.0  11.2   IDCJAC0002                                 86338
# 85  2020.0    7.0  12.8   IDCJAC0002                                 86338
# 86  2020.0    8.0  14.5   IDCJAC0002                                 86338
# 87  2020.0    9.0  17.3   IDCJAC0002                                 86338
# 88  2020.0   10.0  17.4   IDCJAC0002                                 86338
# 89  2020.0   11.0  23.5   IDCJAC0002                                 86338
# 90  2020.0   12.0  21.4   IDCJAC0002                                 86338
#
#     Mean maximum temperature (°C) Quality
# 79                           26.9       Y
# 80                           24.4       Y
# 81                           22.9       Y
# 82                           19.3       Y
# 83                           16.4       Y
# 84                           14.9       Y
# 85                           14.0       Y
# 86                           15.1       Y
# 87                           18.1       Y
# 88                           19.1       Y
# 89                           24.5       Y
# 90                           22.9       Y

# %%
plt.plot(year_2020['Month'], year_2020['Temp'], label='2020 RainTrace')
plt.plot(year_2020['Month'], year_2020['Mean maximum temperature (°C)'], 
         label='2020 Mean maximum temperature (°C)')
plt.legend()
plt.show()

# %%
year_2021 = merged_data.loc[merged_data['Year']==2021]
year_2021
# Out:
#        Year  Month  Temp Product code  Bureau of Meteorology station number  \
# 91   2021.0    1.0  24.2   IDCJAC0002                                 86338
# 92   2021.0    2.0  23.7   IDCJAC0002                                 86338
# 93   2021.0    3.0  21.3   IDCJAC0002                                 86338
# 94   2021.0    4.0  19.5   IDCJAC0002                                 86338
# 95   2021.0    5.0  17.1   IDCJAC0002                                 86338
# 96   2021.0    6.0  14.3   IDCJAC0002                                 86338
# 97   2021.0    7.0  10.2   IDCJAC0002                                 86338
# 98   2021.0    8.0  14.8   IDCJAC0002                                 86338
# 99   2021.0    9.0  17.8   IDCJAC0002                                 86338
# 100  2021.0   10.0  18.9   IDCJAC0002                                 86338
# 101  2021.0   11.0  18.7   IDCJAC0002                                 86338
# 102  2021.0   12.0  22.8   IDCJAC0002                                 86338
#
#      Mean maximum temperature (°C) Quality
# 91                            25.2       Y
# 92                            24.5       Y
# 93                            22.0       Y
# 94                            20.2       Y
# 95                            17.8       Y
# 96                            15.3       Y
# 97                            14.3       Y
# 98                            16.4       Y
# 99                            18.2       Y
# 100                           19.4       Y
# 101                           20.6       Y
# 102                           24.3       Y

# %%
plt.plot(year_2021['Month'], year_2021['Temp'], label='2021 RainTrace')
plt.plot(year_2021['Month'], year_2021['Mean maximum temperature (°C)'], 
         label='2021 Mean maximum temperature (°C)')
plt.legend()
plt.show()

# %%
year_2022 = merged_data.loc[merged_data['Year']==2022]
year_2022
# Out:
#        Year  Month  Temp Product code  Bureau of Meteorology station number  \
# 103  2022.0    1.0  28.2   IDCJAC0002                                 86338
# 104  2022.0    2.0  24.4   IDCJAC0002                                 86338
# 105  2022.0    3.0  23.2   IDCJAC0002                                 86338
# 106  2022.0    4.0  20.7   IDCJAC0002                                 86338
# 107  2022.0    5.0  15.8   IDCJAC0002                                 86338
# 108  2022.0    6.0  13.7   IDCJAC0002                                 86338
# 109  2022.0    7.0  12.4   IDCJAC0002                                 86338
# 110  2022.0    8.0  13.4   IDCJAC0002                                 86338
# 111  2022.0    9.0  16.1   IDCJAC0002                                 86338
# 112  2022.0   10.0  18.6   IDCJAC0002                                 86338
# 113  2022.0   11.0  18.5   IDCJAC0002                                 86338
# 114  2022.0   12.0  22.8   IDCJAC0002                                 86338
#
#      Mean maximum temperature (°C) Quality
# 103                           29.1       Y
# 104                           25.1       Y
# 105                           24.3       Y
# 106                           21.1       Y
# 107                           16.8       Y
# 108                           14.1       Y
# 109                           14.0       Y
# 110                           15.6       Y
# 111                           16.6       Y
# 112                           19.2       Y
# 113                           20.2       Y
# 114                           23.9       Y

# %%
plt.plot(year_2022['Month'], year_2022['Temp'], label='2022 RainTrace')
plt.plot(year_2022['Month'], year_2022['Mean maximum temperature (°C)'], 
         label='2022 Mean maximum temperature (°C)')
plt.legend()
plt.show()

# %%
year_2023 = merged_data.loc[merged_data['Year']==2023]
year_2023
# Out:
#        Year  Month  Temp Product code  Bureau of Meteorology station number  \
# 115  2023.0    1.0  25.4   IDCJAC0002                                 86338
# 116  2023.0    2.0  22.2   IDCJAC0002                                 86338
# 117  2023.0    3.0  22.5   IDCJAC0002                                 86338
#
#      Mean maximum temperature (°C) Quality
# 115                           26.1       Y
# 116                           25.0       Y
# 117                           23.0       Y

# %%
plt.plot(year_2023['Month'], year_2023['Temp'], label='2023 RainTrace')
plt.plot(year_2023['Month'], year_2023['Mean maximum temperature (°C)'], 
         label='2023 Mean maximum temperature (°C)')
plt.legend()
plt.show()
